# %%
# %matplotlib inline
import os
import numpy as np
import matplotlib.pyplot as plt

# Import the Parsers
from openquake.cat.parsers.isf_catalogue_reader import ISFReader
from openquake.cat.parsers.converters import GenericCataloguetoISFParser
from openquake.cat.isc_homogenisor import (HomogenisorPreprocessor,
                                   DynamicHomogenisor,
                                   MagnitudeConversionRule,
                                   DuplicateFinder)

# %% [markdown]
# ## Load in Catalogue - Limit to ISC, GCMT/HRVD, EHB, NEIC, BJI

# %%
isc_parser = ISFReader("inputs/1900-2021-PH_ISF_Catalogue.txt",
                   selected_origin_agencies=["ISC-GEM", "ISC-EHB", "EHB", "ISC", "IDC", "NEIC", "NEIS", "USCGS", "NIED", "GCMT", "GUTE", "PAS"],
                   selected_magnitude_agencies=["ISC-GEM", "ISC-EHB", "EHB", "ISC", "IDC", "NEIC", "NEIS", "USCGS", "NIED", "GCMT", "GUTE", "PAS"])
isc_catalogue = isc_parser.read_file("ISC-RB", "ISC-Global")
print("ISC Reviewed Bulleting Catalogue contains: %d events" % isc_catalogue.get_number_events())

iscgem_parser = GenericCataloguetoISFParser("inputs/isc-gem-cat-3.csv")
iscgem_catalogue = iscgem_parser.parse("ISC-GEM", "ISC-GEM-CAT")

print("ISC-GEM Catalogue contains: %d events" % iscgem_catalogue.get_number_events())
# Out:
# ISC Reviewed Bulleting Catalogue contains: 68488 events
# ISC-GEM Catalogue contains: 3993 events

# %%
isc_catalogue

# %%
merger = DuplicateFinder(iscgem_catalogue, 0.0001, 0.0001, logging=True)
mergedCatalogue = merger.merge_catalogue(isc_catalogue)
# Out:
# After duplicate finding: 72478 events (72478)

# %%
## Define Rule Sets

# %% [markdown]
# The catalogue covers the years 2005/06. To illustrate how to apply time variable hierarchies we consider two set of rules:
#
# For the origin the order of preference is:
#
# (For 2005): EHB, ISC, NEIC, GCMT/HRVD, BJI
#
# (For 2006): ISC, EHB, NEIC, BJI, GCMT/HRVD

# %%
# origin_rules = [
#     ("2015/01/01 - 2021/12/31", ["EHB", "ISC", "NEIC", "GCMT"]),
#     ("2021/01/01 - 2007/01/01", ["EHB", "ISC", "NEIC", "GCMT"])
# ]

origin_rules = [
    ("1900/01/01 - 2021/12/31", ["ISC-GEM", "ISC-EHB", "EHB", "ISC", "IDC", "NEIC", "NEIS", "USCGS", "NIED", "GCMT", "GUTE", "PAS"])
]

# %% [markdown]
# ### Magnitude Rules

# %% [markdown]
# #### GCMT/HRVD

# %%
def gcmt_hrvd_mw(magnitude):
    """
    For Mw recorded by GCMT take the value with no uncertainty
    """
    return magnitude

def gcmt_hrvd_mw_sigma(magnitude):
    """
    No additional uncertainty   
    """
    return 0.0

# %% [markdown]
# #### ISC/NEIC

# %% [markdown]
# #### Weatherill (2015) Table 1. Mw conversions

# %%
"""
Weatherill (2015) Table 1. Mw conversions
"""
def iscgem_mw(magnitude):
    """
    For Mw recorded by ISCGEM take the value with no uncertainty
    """
    return magnitude

def iscgem_mw_sigma(magnitude):
    """
    No additional uncertainty   
    """
    return 0.0

def gcmt_mw(magnitude):
    """
    For Mw recorded by GCMT take the value with no uncertainty
    """
    return magnitude

def gcmt_mw_sigma(magnitude):
    """
    No additional uncertainty   
    """
    return 0.0

def neic_mw(magnitude):
    """
    If Mw reported by NEIC,
    """
    return 1.021 * magnitude - 0.091

def neic_mw_sigma(magnitude):
    """
    Uncertainty of 0.101 units
    """
    return 0.105

def nied_mw(magnitude):
    """
    If Mw reported by NIED,
    """
    return 0.964 * magnitude + 0.248

def nied_mw_sigma(magnitude):
    """
    Uncertainty of 0.11 units
    """
    return 0.11

def isc_ms(magnitude):
    """
    If Ms reported by ISC, convert to Mw from Weatherill (2015),
    """
    if magnitude > 6.0:
        return 0.994 * magnitude + 0.1        
    else:
        return 0.616 * magnitude + 2.369

def isc_ms_sigma(magnitude):
    """
    With Magnitude dependent uncertainty
    """
    if magnitude > 6.0:
        return 0.174
    else:
        return 0.147

def neic_ms(magnitude):
    """
    If Ms reported by NEIC, convert to Mw from Weatherill (2015),
    """
    if magnitude > 6.47:
        return 1.005 * magnitude - 0.026       
    else:
        return 0.723 * magnitude + 1.798

def neic_ms_sigma(magnitude):
    """
    With Magnitude dependent uncertainty
    """
    if magnitude > 6.47:
        return 0.187
    else:
        return 0.159
    
def neic_msz(magnitude):
    """
    If Msz reported by NEIC, convert to Mw from Weatherill (2015),
    """
    if magnitude > 6.47:
        return 0.950 * magnitude + 0.359     
    else:
        return 0.707 * magnitude + 1.933

def neic_msz_sigma(magnitude):
    """
    With Magnitude dependent uncertainty
    """
    if magnitude > 6.47:
        return 0.204
    else:
        return 0.179

def neic_mb(magnitude):
    """
    If Mb reported by NEIC,
    """
    return 1.159 * magnitude - 0.659

def neic_mb_sigma(magnitude):
    """
    Uncertainty of 0.283 units
    """
    return 0.283

def isc_mb(magnitude):
    """
    If Mw reported by isc,
    """
    return 1.084 * magnitude - 0.142

def isc_mb_sigma(magnitude):
    """
    Uncertainty of 0.317 units
    """
    return 0.317

def pas_ms(magnitude):
    """
    For Ms recorded by paS take the value with no uncertainty. 
    In their database Pacheco & Sykes (1992) use
    the 20-s period Ms value, which, for our purposes, we treat as
    equivalent to MW in the magnitude range 7.0 ≤ MW ≤ 8.0. (Weatherill, 2015)
    """
    return magnitude

def pas_ms_sigma(magnitude):
    """
    0.2 additional uncertainty   
    """
    return 0.2

# %% [markdown]
# ### Define Magnitude Hierarchy

# %%
# rule_set_2015 = [
#     MagnitudeConversionRule("GCMT", "Mw", gcmt_hrvd_mw, gcmt_hrvd_mw_sigma),
#     MagnitudeConversionRule("HRVD", "Mw", gcmt_hrvd_mw, gcmt_hrvd_mw_sigma),
#     MagnitudeConversionRule("ISC", "Ms", scordillis_ms, scordillis_ms_sigma),
#     MagnitudeConversionRule("NEIC", "Ms", scordillis_ms, scordillis_ms_sigma),
#     MagnitudeConversionRule("ISC", "mb", scordillis_mb, scordillis_mb_sigma),
#     MagnitudeConversionRule("NEIC", "mb", scordillis_mb, scordillis_mb_sigma),
#     MagnitudeConversionRule("BJI", "Ms", bji_ms, bji_ms_sigma),
#     MagnitudeConversionRule("BJI", "mb", bji_mb, bji_mb_sigma)
# ]

# rule_set_2006 = [
#     MagnitudeConversionRule("GCMT", "Mw", gcmt_hrvd_mw, gcmt_hrvd_mw_sigma),
#     MagnitudeConversionRule("HRVD", "Mw", gcmt_hrvd_mw, gcmt_hrvd_mw_sigma),
#     MagnitudeConversionRule("ISC", "Ms", scordillis_ms, scordillis_ms_sigma),
#     MagnitudeConversionRule("BJI", "Ms", bji_ms, bji_ms_sigma),
#     MagnitudeConversionRule("NEIC", "Ms", scordillis_ms, scordillis_ms_sigma),
#     MagnitudeConversionRule("ISC", "mb", scordillis_mb, scordillis_mb_sigma),
#     MagnitudeConversionRule("BJI", "mb", bji_mb, bji_mb_sigma),
#     MagnitudeConversionRule("NEIC", "mb", scordillis_mb, scordillis_mb_sigma)
#]

rule_set_1900 = [
    MagnitudeConversionRule("ISC-GEM", "Mw", iscgem_mw, iscgem_mw_sigma),
    MagnitudeConversionRule("GCMT", "Mw", gcmt_mw, gcmt_mw_sigma),
    MagnitudeConversionRule("NEIC", "Mw", neic_mw, neic_mw_sigma),
    MagnitudeConversionRule("NIED", "Mw", nied_mw, nied_mw_sigma),
    MagnitudeConversionRule("ISC", "Ms", isc_ms, isc_ms_sigma),
    MagnitudeConversionRule("IDC", "Ms", isc_ms, isc_ms_sigma),
    MagnitudeConversionRule("NEIC", "Ms", neic_ms, neic_ms_sigma),
    MagnitudeConversionRule("USCGS", "Ms", neic_ms, neic_ms_sigma),
    MagnitudeConversionRule("NEIC", "Msz", neic_msz, neic_msz_sigma),
    MagnitudeConversionRule("NEIC", "Mb", neic_mb, neic_mb_sigma),
    MagnitudeConversionRule("USCGS", "Mb", neic_mb, neic_mb_sigma),
    MagnitudeConversionRule("ISC", "Mb", isc_mb, isc_mb_sigma),
    MagnitudeConversionRule("PAS", "Ms", pas_ms, pas_ms_sigma),
]

# magnitude_rules = [
#     ("2015/01/01 - 2021/12/31", rule_set_2005),
#     ("2006/01/01 - 2007/01/01", rule_set_2006)
# ]

magnitude_rules = [
    ("1900/01/01 - 2021/12/31", rule_set_1900)
]

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# Before executing the homogenisation it is necessary to run a preprocessing step. This searches through the catalogue and identifies which conversion rule to apply:
#
# The preprocessor is instantiated with a string describing the sort of rules to be applied.
#
# "time" - Applies time only
#
# "key" - Applies key rules only
#
# "depth" - Applies depth rules only
#
# "time|key" - Applies joint time and key rules
#
# "time|depth" - Applied joint time and depth rules
#
# "depth|key" - Applies joint depth and key rules

# %%
preprocessor = HomogenisorPreprocessor("time")
catalogue = preprocessor.execute(mergedCatalogue, origin_rules, magnitude_rules)
# catalogue = preprocessor.execute(isc_catalogue, origin_rules, magnitude_rules)

# %% [markdown]
# ### Harmonise the Catalogue

# %%
harmonisor = DynamicHomogenisor(catalogue, logging=True)
homogenised_catalogue = harmonisor.homogenise(magnitude_rules, origin_rules)
# Out:
# 610548604 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 610548608 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 610548621 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16957889 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16957892 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16957904 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16957903 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16957908 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 610548662 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 610548664 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16957926 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 914258 PAS-Ms GUTE|PAS-Ms
# 914262 PAS-Ms GUTE|PAS-Ms
# 16957953 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 914263 PAS-Ms GUTE|PAS-Ms
# 16957952 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 610548683 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 610548685 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 610548686 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16957964 PAS-Ms ISC|PAS-Ms
# 16957967 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16957968 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 610548699 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 610548707 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 610326336 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16957982 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16957985 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 914225 PAS-Ms GUTE|PAS-Ms
# 16958027 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 914226 PAS-Ms GUTE|PAS-Ms
# 16958091 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16958104 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16958115 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16958127 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16958127 ISC-Ms ISC|ISC-Ms
# 610643057 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 914153 PAS-Ms GUTE|PAS-Ms
# 16958154 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16
ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902663 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902664 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902664 ISC-Ms ISC|ISC-Ms
# 902710 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902710 ISC-Ms ISC|ISC-Ms
# 902711 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902711 ISC-Ms ISC|ISC-Ms
# 902713 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902713 ISC-Ms ISC|ISC-Ms
# 902788 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 9342032 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902854 ISC-Ms ISC|ISC-Ms
# 902854 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902856 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902859 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902861 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902876 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902883 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901802 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901811 PAS-Ms GUTE|PAS-Ms
# 901811 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901883 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 16965231 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901940 PAS-Ms GUTE|PAS-Ms
# 901940 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901971 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901989 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902001 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902001 ISC-Ms ISC|ISC-Ms
# 902027 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902045 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902045 ISC-Ms ISC|ISC-Ms
# 902127 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902130 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902136 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902150 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 902150 PAS-Ms GUTE|PAS-Ms
# 901209 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901257 PAS-Ms ISC|PAS-Ms
# 901269 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901280 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901403 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901438 PAS-Ms GUTE|PAS-Ms
# 901499 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901499 ISC-Ms ISC|ISC-Ms
# 901524 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901561 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901573 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901575 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901580 PAS-Ms GUTE|PAS-Ms
# 901602 PAS-Ms ISC|PAS-Ms
# 901625 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901639 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901639 PAS-Ms ISC|PAS-Ms
# 901660 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901738 PAS-Ms GUTE|PAS-Ms
# 901738 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900608 PAS-Ms GUTE|PAS-Ms
# 900611 ISC-Ms ISC|ISC-Ms
# 900619 PAS-Ms GUTE|PAS-Ms
# 900643 PAS-Ms ISC|PAS-Ms
# 900648 PAS-Ms GUTE|PAS-Ms
# 900650 PAS-Ms GUTE|PAS-Ms
# 900684 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900684 PAS-Ms GUTE|PAS-Ms
# 900770 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900800 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900800 ISC-Ms ISC|ISC-Ms
# 900847 PAS-Ms GUTE|PAS-Ms
# 900847 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900913 PAS-Ms GUTE|PAS-Ms
# 901063 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901063 ISC-Ms ISC|ISC-Ms
# 901124 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 901124 ISC-Ms ISC|ISC-Ms
# 900174 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900228 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900244 ISC-Ms ISC|ISC-Ms
# 900244 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900245 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900246 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900247 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900299 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900323 ISC-Ms ISC|ISC-Ms
# 900323 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900330 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900397 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900397 ISC-Ms ISC|ISC-Ms
# 900471 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900480 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900480 ISC-Ms ISC|ISC-Ms
# 900504 ISC-Ms ISC|ISC-Ms
# 900504 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900574 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899773 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899803 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899838 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899838 ISC-Ms ISC|ISC-Ms
# 899851 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899851 ISC-Ms ISC|ISC-Ms
# 899909 PAS-Ms GUTE|PAS-Ms
# 899922 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899959 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899971 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900078 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900100 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900100 ISC-Ms ISC|ISC-Ms
# 900108 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900118 ISC-Ms ISC|ISC-Ms
# 900118 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 900127 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899290 ISC-Ms ISC|ISC-Ms
# 899290 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899507 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899508 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899539 ISC-Ms ISC|ISC-Ms
# 899564 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899580 PAS-Ms ISC|PAS-Ms
# 899618 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899618 ISC-Ms ISC|ISC-Ms
# 898755 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 898780 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 898782 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 898834 PAS-Ms ISC|PAS-Ms
# 898861 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 898898 PAS-Ms ISC|PAS-Ms
# 899016 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899016 ISC-Ms ISC|ISC-Ms
# 899017 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899150 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899225 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 899239 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 898225 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 898257 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 898573 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 898645 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 898682 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897709 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897814 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897828 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897829 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897865 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897883 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897883 ISC-Ms ISC|ISC-Ms
# 897886 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897890 ISC-Ms ISC|ISC-Ms
# 898187 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897163 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897163 ISC-Ms ISC|ISC-Ms
# 897165 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897166 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897169 ISC-Ms ISC|ISC-Ms
# 897183 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897220 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897220 ISC-Ms ISC|ISC-Ms
# 897241 ISC-Ms ISC|ISC-Ms
# 897248 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897404 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897508 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897531 PAS-Ms ISC|PAS-Ms
# 897567 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897576 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 896278 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 896328 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 896433 ISC-Ms ISC|ISC-Ms
# 896433 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 896436 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 896492 PAS-Ms ISC|PAS-Ms
# 896830 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 896831 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 896854 ISC-Ms ISC|ISC-Ms
# 896923 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897011 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897130 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 897130 ISC-Ms ISC|ISC-Ms
# 895106 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 895106 ISC-Ms ISC|ISC-Ms
# 895280 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 895280 ISC-Ms ISC|ISC-Ms
# 895485 ISC-Ms ISC|ISC-Ms
# 895485 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 895544 ISC-Ms ISC|ISC-Ms
# 895544 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 895605 ISC-Ms ISC|ISC-Ms
# 895605 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 895637 ISC-Ms ISC|ISC-Ms
# 895637 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 895658 -- None --  None
# 895661 ISC-Ms ISC|ISC-Ms
# 895776 -- None --  None
# 895864 ISC-Ms ISC|ISC-Ms
# 895864 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 895869 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 895869 ISC-Ms ISC|ISC-Ms
# 894056 ISC-Ms ISC|ISC-Ms
# 894351 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894351 ISC-Ms ISC|ISC-Ms
# 894383 ISC-Ms ISC|ISC-Ms
# 894383 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894388 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894388 ISC-Ms ISC|ISC-Ms
# 894390 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894437 ISC-Ms ISC|ISC-Ms
# 894437 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894468 ISC-Ms ISC|ISC-Ms
# 894468 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894490 ISC-Ms ISC|ISC-Ms
# 894490 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894821 ISC-Ms ISC|ISC-Ms
# 894821 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894824 ISC-Ms ISC|ISC-Ms
# 894824 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894825 ISC-Ms ISC|ISC-Ms
# 894825 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894826 ISC-Ms ISC|ISC-Ms
# 894826 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894828 ISC-Ms ISC|ISC-Ms
# 894828 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894830 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894831 ISC-Ms ISC|ISC-Ms
# 894831 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894833 ISC-Ms ISC|ISC-Ms
# 894833 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894835 ISC-Ms ISC|ISC-Ms
# 894835 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894838 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894838 ISC-Ms ISC|ISC-Ms
# 894840 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894840 ISC-Ms ISC|ISC-Ms
# 894842 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894842 ISC-Ms ISC|ISC-Ms
# 894844 ISC-Ms ISC|ISC-Ms
# 894844 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894846 ISC-Ms ISC|ISC-Ms
# 894846 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894849 ISC-Ms ISC|ISC-Ms
# 894849 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894850 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894884 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894884 ISC-Ms ISC|ISC-Ms
# 894903 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894903 ISC-Ms ISC|ISC-Ms
# 894987 ISC-Ms ISC|ISC-Ms
# 894987 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894988 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 894988 ISC-Ms ISC|ISC-Ms
# 894992 ISC-Ms ISC|ISC-Ms
# 894992 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 895010 ISC-Ms ISC|ISC-Ms
# 895010 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 895090 ISC-Ms ISC|ISC-Ms
# 895090 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 892380 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 892380 ISC-Ms ISC|ISC-Ms
# 892428 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 892428 ISC-Ms ISC|ISC-Ms
# 892651 ISC-Ms ISC|ISC-Ms
# 892651 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 892671 ISC-Ms ISC|ISC-Ms
# 892671 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 892741 ISC-Ms ISC|ISC-Ms
# 892741 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 892768 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 892768 ISC-Ms ISC|ISC-Ms
# 892875 -- None --  None
# 892900 ISC-Ms ISC|ISC-Ms
# 892900 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 892908 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 893050 -- None --  None
# 893963 ISC-Ms ISC|ISC-Ms
# 893963 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 891447 -- None --  None
# 891535 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 891552 ISC-Ms ISC|ISC-Ms
# 891552 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 891610 ISC-Ms ISC|ISC-Ms
# 891610 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 891616 ISC-Ms ISC|ISC-Ms
# 891616 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 892288 ISC-Ms ISC|ISC-Ms
# 892288 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 892313 ISC-Ms ISC|ISC-Ms
# 892313 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 890239 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 890239 ISC-Ms ISC|ISC-Ms
# 890480 ISC-Ms ISC|ISC-Ms
# 890480 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 890688 ISC-Ms ISC|ISC-Ms
# 890688 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 890805 ISC-Ms ISC|ISC-Ms
# 890805 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 890810 ISC-Ms ISC|ISC-Ms
# 890810 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 890980 ISC-Ms ISC|ISC-Ms
# 890980 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 891027 ISC-Ms ISC|ISC-Ms
# 891027 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 891037 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 891039 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 891039 ISC-Ms ISC|ISC-Ms
# 891040 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 891041 ISC-Ms ISC|ISC-Ms
# 891041 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 891064 ISC-Ms ISC|ISC-Ms
# 891064 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 891065 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 891065 ISC-Ms ISC|ISC-Ms
# 889217 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 889217 ISC-Ms ISC|ISC-Ms
# 889287 ISC-Ms ISC|ISC-Ms
# 889287 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 889288 ISC-Ms ISC|ISC-Ms
# 889288 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 889384 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 889384 ISC-Ms ISC|ISC-Ms
# 889385 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 889385 ISC-Ms ISC|ISC-Ms
# 889391 ISC-Ms ISC|ISC-Ms
# 889391 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 889411 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 889411 ISC-Ms ISC|ISC-Ms
# 889539 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 889659 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 889659 ISC-Ms ISC|ISC-Ms
# 889780 ISC-Ms ISC|ISC-Ms
# 889780 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 889784 ISC-Ms ISC|ISC-Ms
# 889784 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 889948 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 889948 ISC-Ms ISC|ISC-Ms
# 889953 -- None --  None
# 889999 ISC-Ms ISC|ISC-Ms
# 889999 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 890118 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 890180 ISC-Ms ISC|ISC-Ms
# 890180 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 887884 ISC-Ms ISC|ISC-Ms
# 887884 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 887943 ISC-Ms ISC|ISC-Ms
# 887943 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 887948 ISC-Ms ISC|ISC-Ms
# 887948 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 887956 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 887957 ISC-Ms ISC|ISC-Ms
# 887957 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 888497 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 888497 ISC-Ms ISC|ISC-Ms
# 888517 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 888517 ISC-Ms ISC|ISC-Ms
# 888823 ISC-Mb ISC|ISC-Mb
# 888823 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 888842 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 888842 ISC-Ms ISC|ISC-Ms
# 888886 ISC-Ms ISC|ISC-Ms
# 888886 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 885935 ISC-Ms ISC|ISC-Ms
# 885935 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 885936 ISC-Ms ISC|ISC-Ms
# 885936 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 885937 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 885937 ISC-Ms ISC|ISC-Ms
# 885944 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 885944 ISC-Ms ISC|ISC-Ms
# 885950 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 885950 ISC-Ms ISC|ISC-Ms
# 885987 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 885987 ISC-Ms ISC|ISC-Ms
# 886456 ISC-Ms ISC|ISC-Ms
# 886475 ISC-Ms ISC|ISC-Ms
# 886475 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 886670 ISC-Ms ISC|ISC-Ms
# 886670 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 886693 ISC-Ms ISC|ISC-Ms
# 886693 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 887045 ISC-Ms ISC|ISC-Ms
# 887045 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 
# 849176 USCGS-Mb ISC|USCGS-Mb
# 849178 USCGS-Mb ISC|USCGS-Mb
# 849180 USCGS-Mb ISC|USCGS-Mb
# 849182 USCGS-Mb ISC|USCGS-Mb
# 849184 USCGS-Mb ISC|USCGS-Mb
# 849187 USCGS-Mb ISC|USCGS-Mb
# 849189 USCGS-Mb ISC|USCGS-Mb
# 849192 USCGS-Mb ISC-EHB|USCGS-Mb
# 849196 USCGS-Mb ISC|USCGS-Mb
# 849198 USCGS-Mb ISC|USCGS-Mb
# 849199 USCGS-Mb ISC|USCGS-Mb
# 849200 USCGS-Mb ISC|USCGS-Mb
# 849201 USCGS-Mb ISC|USCGS-Mb
# 849202 USCGS-Mb ISC|USCGS-Mb
# 849210 USCGS-Mb ISC-EHB|USCGS-Mb
# 849212 USCGS-Mb ISC|USCGS-Mb
# 849218 USCGS-Mb ISC|USCGS-Mb
# 849225 USCGS-Mb ISC|USCGS-Mb
# 849235 USCGS-Mb ISC-EHB|USCGS-Mb
# 849311 USCGS-Mb ISC|USCGS-Mb
# ...
# 620222018 ISC-Ms ISC|ISC-Ms
# 620352659 -- None --  None
# 620352663 ISC-Mb ISC|ISC-Mb
# 620352669 -- None --  None
# 620352675 ISC-Mb ISC|ISC-Mb
# 620352681 -- None --  None
# 620354029 NEIC-Mb ISC|NEIC-Mb
# 620354039 -- None --  None
# 620354052 IDC-Ms ISC|IDC-Ms
# 620354059 ISC-Mb ISC|ISC-Mb
# 620354071 IDC-Ms IDC|IDC-Ms
# 620227308 GCMT-Mw ISC|GCMT-Mw
# 620354090 -- None --  None
# 620228435 NIED-Mw ISC|NIED-Mw
# 620354145 IDC-Ms ISC|IDC-Ms
# 620354156 IDC-Ms ISC|IDC-Ms
# 620354173 NEIC-Mb ISC|NEIC-Mb
# 620341405 NEIC-Mb ISC|NEIC-Mb
# 620341407 -- None --  None
# 620341409 IDC-Ms ISC|IDC-Ms
# 620341412 NEIC-Mb ISC|NEIC-Mb
# 620228715 GCMT-Mw ISC|GCMT-Mw
# 620341460 NEIC-Mb ISC|NEIC-Mb
# 620341466 NEIC-Mb ISC|NEIC-Mb
# 620341476 ISC-Mb ISC|ISC-Mb
# 620341482 IDC-Ms IDC|IDC-Ms
# 620341489 -- None --  None
# 620341493 IDC-Ms ISC|IDC-Ms
# 620341523 IDC-Ms ISC|IDC-Ms
# 620341524 NEIC-Mb ISC|NEIC-Mb
# 620236354 NEIC-Mb ISC|NEIC-Mb
# 620341561 ISC-Ms ISC|ISC-Ms
# 620236366 ISC-Ms ISC|ISC-Ms
# 620236519 GCMT-Mw ISC|GCMT-Mw
# 620341617 -- None --  None
# 625465839 ISC-Mb ISC|ISC-Mb
# 620341664 -- None --  None
# 620341677 ISC-Mb ISC|ISC-Mb
# 620341680 -- None --  None
# 620341721 ISC-Mb ISC|ISC-Mb
# 620341729 ISC-Mb ISC|ISC-Mb
# 620341731 ISC-Mb ISC|ISC-Mb
# 620236891 GCMT-Mw ISC|GCMT-Mw
# 620341771 IDC-Ms ISC|IDC-Ms
# 620341781 -- None --  None
# 620341804 NEIC-Mb ISC|NEIC-Mb
# 620341821 ISC-Mb ISC|ISC-Mb
# 620341827 IDC-Ms ISC|IDC-Ms
# 620341833 NEIC-Mb ISC|NEIC-Mb
# 620238393 GCMT-Mw ISC|GCMT-Mw
# 620238394 GCMT-Mw ISC|GCMT-Mw
# 620341853 -- None --  None
# 620341854 ISC-Mb ISC|ISC-Mb
# 620341878 ISC-Ms ISC|ISC-Ms
# 620289726 NIED-Mw ISC|NIED-Mw
# 620341891 NEIC-Mb ISC|NEIC-Mb
# 620291955 ISC-Ms ISC|ISC-Ms
# 620341901 NEIC-Mb ISC|NEIC-Mb
# 620295806 NEIC-Mb ISC|NEIC-Mb
# 620341910 NIED-Mw ISC|NIED-Mw
# 620341911 NEIC-Mb ISC|NEIC-Mb
# 620341922 NIED-Mw ISC|NIED-Mw
# 620341923 IDC-Ms ISC|IDC-Ms
# 620343894 NEIC-Mb ISC|NEIC-Mb
# 620343910 -- None --  None
# 620343915 ISC-Mb ISC|ISC-Mb
# 620343916 ISC-Mb ISC|ISC-Mb
# 620343921 ISC-Mb ISC|ISC-Mb
# 620343934 ISC-Mb ISC|ISC-Mb
# 620343935 -- None --  None
# 620344818 IDC-Ms ISC|IDC-Ms
# 620301606 NIED-Mw ISC|NIED-Mw
# 620344822 NEIC-Mb ISC|NEIC-Mb
# 620323188 IDC-Ms ISC|IDC-Ms
# 620344845 -- None --  None
# 620323193 NIED-Mw ISC|NIED-Mw
# 620323324 GCMT-Mw ISC|GCMT-Mw
# 620344867 ISC-Mb ISC|ISC-Mb
# 620344876 -- None --  None
# 620344884 IDC-Ms IDC|IDC-Ms
# 620344891 ISC-Ms ISC|ISC-Ms
# 620344914 -- None --  None
# 620344919 ISC-Mb ISC|ISC-Mb
# 620344923 IDC-Ms ISC|IDC-Ms
# 620344924 ISC-Mb ISC|ISC-Mb
# 620344926 ISC-Mb ISC|ISC-Mb
# 620344930 ISC-Mb ISC|ISC-Mb
# 620344933 -- None --  None
# 620346562 -- None --  None
# 620346598 ISC-Mb ISC|ISC-Mb
# 620342014 ISC-Ms ISC|ISC-Ms
# 620342043 GCMT-Mw ISC|GCMT-Mw
# 625678667 GCMT-Mw ISC|GCMT-Mw
# 620346626 NEIC-Mb ISC|NEIC-Mb
# 620342031 NEIC-Mb ISC|NEIC-Mb
# 620346635 IDC-Ms IDC|IDC-Ms
# 620346679 NEIC-Mb ISC|NEIC-Mb
# 620346727 NEIC-Mb ISC|NEIC-Mb
# 620350210 IDC-Ms ISC|IDC-Ms
# 620346728 IDC-Ms ISC|IDC-Ms
# 620350214 IDC-Ms ISC|IDC-Ms
# 620350218 -- None --  None
# 620350243 IDC-Ms IDC|IDC-Ms
# 620350252 NEIC-Mb ISC|NEIC-Mb
# 620352755 -- None --  None
# 620351933 ISC-Ms ISC|ISC-Ms
# 620351959 -- None --  None
# 620351961 IDC-Ms ISC|IDC-Ms
# 620351985 IDC-Ms ISC|IDC-Ms
# 620351992 NEIC-Mb ISC|NEIC-Mb
# 620353064 NEIC-Mb ISC|NEIC-Mb
# 620342098 ISC-Ms ISC|ISC-Ms
# 620342092 ISC-Ms ISC|ISC-Ms
# 620354217 ISC-Mb ISC|ISC-Mb
# 620354219 -- None --  None
# 620354226 IDC-Ms ISC|IDC-Ms
# 620342195 ISC-Ms ISC|ISC-Ms
# 620354246 IDC-Ms ISC|IDC-Ms
# 620342200 ISC-Ms ISC|ISC-Ms
# 620354251 IDC-Ms ISC|IDC-Ms
# 620342203 NEIC-Mb ISC|NEIC-Mb
# 620354258 IDC-Ms IDC|IDC-Ms
# 620342213 GCMT-Mw ISC|GCMT-Mw
# 620354275 ISC-Mb ISC|ISC-Mb
# 620354279 ISC-Mb ISC|ISC-Mb
# 620342220 IDC-Ms ISC|IDC-Ms
# 620342299 ISC-Ms ISC|ISC-Ms
# 620354309 ISC-Mb ISC|ISC-Mb
# 620356507 ISC-Mb ISC|ISC-Mb
# 620356540 IDC-Ms ISC|IDC-Ms
# 620356542 NEIC-Mb ISC|NEIC-Mb
# 620356543 IDC-Ms ISC|IDC-Ms
# 620356557 IDC-Ms ISC|IDC-Ms
# 625887665 IDC-Ms IDC|IDC-Ms
# 620342435 IDC-Ms ISC|IDC-Ms
# 620356601 -- None --  None
# 620356608 -- None --  None
# 620356632 NEIC-Mb ISC|NEIC-Mb
# 620356637 ISC-Mb ISC|ISC-Mb
# 620360809 -- None --  None
# 620351399 NEIC-Mb ISC|NEIC-Mb
# 620360831 IDC-Ms IDC|IDC-Ms
# 620351401 IDC-Ms ISC|IDC-Ms
# 620342589 NEIC-Mb ISC|NEIC-Mb
# 620360849 NEIC-Mb ISC|NEIC-Mb
# 620342591 NEIC-Mb ISC|NEIC-Mb
# 620343967 IDC-Ms ISC|IDC-Ms
# 620343968 ISC-Ms ISC|ISC-Ms
# 620343963 NIED-Mw ISC|NIED-Mw
# 620360873 IDC-Ms ISC|IDC-Ms
# 620364175 ISC-Ms ISC|ISC-Ms
# 620364208 -- None --  None
# 620364246 IDC-Ms IDC|IDC-Ms
# 625658422 ISC-Mb ISC|ISC-Mb
# 620364260 ISC-Mb ISC|ISC-Mb
# 620368457 -- None --  None
# 620345057 ISC-Ms ISC|ISC-Ms
# 620368480 NEIC-Mb ISC|NEIC-Mb
# 620345091 GCMT-Mw ISC|GCMT-Mw
# 620345093 NIED-Mw ISC|NIED-Mw
# 620354686 NIED-Mw ISC|NIED-Mw
# 620354687 NIED-Mw ISC|NIED-Mw
# 620354688 NIED-Mw ISC|NIED-Mw
# 620354689 NIED-Mw ISC|NIED-Mw
# 620368527 IDC-Ms IDC|IDC-Ms
# 620368529 IDC-Ms ISC|IDC-Ms
# 620368575 IDC-Ms ISC|IDC-Ms
# 620368586 IDC-Ms ISC|IDC-Ms
# 620368602 IDC-Ms IDC|IDC-Ms
# 620376310 NEIC-Mb ISC|NEIC-Mb
# 620376320 -- None --  None
# 620376332 ISC-Mb ISC|ISC-Mb
# 620376337 ISC-Mb ISC|ISC-Mb
# 625680606 ISC-Mb ISC|ISC-Mb
# 620348985 GCMT-Mw ISC|GCMT-Mw
# 620376358 IDC-Ms IDC|IDC-Ms
# 620376367 IDC-Ms ISC|IDC-Ms
# 620376373 ISC-Mb ISC|ISC-Mb
# 620376395 NIED-Mw ISC|NIED-Mw
# 620376400 ISC-Mb ISC|ISC-Mb
# 620386331 -- None --  None
# 620386351 ISC-Mb ISC|ISC-Mb
# 620350339 IDC-Ms ISC|IDC-Ms
# 620386357 ISC-Mb ISC|ISC-Mb
# 620386359 ISC-Mb ISC|ISC-Mb
# 620386360 IDC-Ms ISC|IDC-Ms
# 620386362 ISC-Mb ISC|ISC-Mb
# 620397696 NEIC-Mb ISC|NEIC-Mb
# 620397698 ISC-Mb ISC|ISC-Mb
# 620397716 IDC-Ms ISC|IDC-Ms
# 620353097 GCMT-Mw ISC|GCMT-Mw
# 620397755 IDC-Ms ISC|IDC-Ms
# 625770800 ISC-Mb ISC|ISC-Mb
# 620397761 IDC-Ms ISC|IDC-Ms
# 620397774 -- None --  None
# 620356659 ISC-Ms ISC|ISC-Ms
# 620354419 GCMT-Mw ISC|GCMT-Mw
# 620422418 IDC-Ms ISC|IDC-Ms
# 620422420 IDC-Ms ISC|IDC-Ms
# 620422423 IDC-Ms ISC|IDC-Ms
# 620354438 ISC-Ms ISC|ISC-Ms
# 620422425 NIED-Mw ISC|NIED-Mw
# 620422428 IDC-Ms IDC|IDC-Ms
# 620356654 NEIC-Mb ISC|NEIC-Mb
# 620422440 IDC-Ms ISC|IDC-Ms
# 620422457 IDC-Ms ISC|IDC-Ms
# 620422461 -- None --  None
# 620356687 IDC-Ms ISC|IDC-Ms
# 620356688 GCMT-Mw ISC|GCMT-Mw
# 620422480 NEIC-Mb ISC|NEIC-Mb
# 620422493 IDC-Ms IDC|IDC-Ms
# 620422494 ISC-Mb ISC|ISC-Mb
# 620422501 ISC-Mb ISC|ISC-Mb
# 620356800 NIED-Mw ISC|NIED-Mw
# 620422514 ISC-Mb ISC|ISC-Mb
# 620437685 ISC-Mb ISC|ISC-Mb
# 620437688 NIED-Mw ISC|NIED-Mw
# 620437689 IDC-Ms ISC|IDC-Ms
# 620356821 ISC-Mb ISC|ISC-Mb
# 620437697 IDC-Ms ISC|IDC-Ms
# 620437702 IDC-Ms ISC|IDC-Ms
# 620357262 ISC-Ms ISC|ISC-Ms
# 620437725 ISC-Mb ISC|ISC-Mb
# 620437748 ISC-Mb ISC|ISC-Mb
# 620437771 -- None --  None
# 620437774 IDC-Ms IDC|IDC-Ms
# 620437780 IDC-Ms ISC|IDC-Ms
# 620437783 ISC-Ms ISC|ISC-Ms
# 620437784 ISC-Mb ISC|ISC-Mb
# 620437801 ISC-Mb ISC|ISC-Mb
# 620437807 IDC-Ms ISC|IDC-Ms
# 620439239 ISC-Ms ISC|ISC-Ms
# 620439240 ISC-Ms ISC|ISC-Ms
# 620439248 NEIC-Mb ISC|NEIC-Mb
# 620439265 ISC-Mb ISC|ISC-Mb
# 620439268 IDC-Ms IDC|IDC-Ms
# 620439273 ISC-Mb ISC|ISC-Mb
# 620439282 ISC-Mb ISC|ISC-Mb
# 620439284 ISC-Mb ISC|ISC-Mb
# 620357396 GCMT-Mw ISC|GCMT-Mw
# 620439300 ISC-Ms ISC|ISC-Ms
# 620357428 NEIC-Mb ISC|NEIC-Mb
# 620440503 ISC-Mb ISC|ISC-Mb
# 620440514 NEIC-Mb ISC|NEIC-Mb
# 620361179 GCMT-Mw ISC|GCMT-Mw
# 620361189 IDC-Ms ISC|IDC-Ms
# 620363931 ISC-Ms ISC|ISC-Ms
# 620363940 IDC-Ms ISC|IDC-Ms
# 625361804 GCMT-Mw ISC|GCMT-Mw
# 620442372 IDC-Ms ISC|IDC-Ms
# 620442397 -- None --  None
# 620442419 NEIC-Mb ISC|NEIC-Mb
# 620368640 IDC-Ms ISC|IDC-Ms
# 620443752 ISC-Mb ISC|ISC-Mb
# 620443755 ISC-Mb ISC|ISC-Mb
# 620443763 NEIC-Mb ISC|NEIC-Mb
# 620376450 NEIC-Mb ISC|NEIC-Mb
# 620443771 ISC-Mb ISC|ISC-Mb
# 620443824 ISC-Mb ISC|ISC-Mb
# 620443832 ISC-Mb ISC|ISC-Mb
# 620376702 IDC-Ms ISC|IDC-Ms
# 620443872 IDC-Ms ISC|IDC-Ms
# 620443878 ISC-Mb ISC|ISC-Mb
# 620445211 NEIC-Mb ISC|NEIC-Mb
# 620445218 IDC-Ms ISC|IDC-Ms
# 620445219 IDC-Ms ISC|IDC-Ms
# 620377170 ISC-Ms ISC|ISC-Ms
# 620445284 NEIC-Mb ISC|NEIC-Mb
# 620445290 NEIC-Mb ISC|NEIC-Mb
# 620448610 IDC-Ms ISC|IDC-Ms
# 620448616 IDC-Ms IDC|IDC-Ms
# 620448627 NEIC-Mb ISC|NEIC-Mb
# 620448646 NIED-Mw ISC|NIED-Mw
# 620465314 ISC-Mb ISC|ISC-Mb
# 620465321 IDC-Ms ISC|IDC-Ms
# 620465327 NEIC-Mb ISC|NEIC-Mb
# 620465328 NEIC-Mb ISC|NEIC-Mb
# 620465330 NEIC-Mb ISC|NEIC-Mb
# 620489188 IDC-Ms ISC|IDC-Ms
# 620489206 NEIC-Mb ISC|NEIC-Mb
# 620429333 IDC-Ms ISC|IDC-Ms
# 620489215 -- None --  None
# 620433900 ISC-Ms ISC|ISC-Ms
# 620489233 IDC-Ms ISC|IDC-Ms
# 620489234 -- None --  None
# 620489235 ISC-Mb ISC|ISC-Mb
# 620505078 -- None --  None
# 620437833 IDC-Ms ISC|IDC-Ms
# 620505235 NEIC-Mb ISC|NEIC-Mb
# 620505242 NEIC-Mb ISC|NEIC-Mb
# 620505254 ISC-Mb ISC|ISC-Mb
# 620505269 ISC-Mb ISC|ISC-Mb
# 620505299 IDC-Ms ISC|IDC-Ms
# 620438148 NIED-Mw ISC|NIED-Mw
# 620505309 ISC-Mb ISC|ISC-Mb
# 620505318 NEIC-Mb ISC|NEIC-Mb
# 620438168 GCMT-Mw ISC|GCMT-Mw
# 620438175 GCMT-Mw ISC|GCMT-Mw
# 620507146 IDC-Ms ISC|IDC-Ms
# 620507158 IDC-Ms IDC|IDC-Ms
# 620507165 ISC-Mb ISC|ISC-Mb
# 620438335 NEIC-Mb ISC|NEIC-Mb
# 620507175 NEIC-Mb ISC|NEIC-Mb
# 620507182 IDC-Ms ISC|IDC-Ms
# 620507184 -- None --  None
# 620507190 ISC-Mb ISC|ISC-Mb
# 620507193 IDC-Ms ISC|IDC-Ms
# 620507215 IDC-Ms ISC|IDC-Ms
# 620507245 NEIC-Mb ISC|NEIC-Mb
# 620507246 -- None --  None
# 620507253 -- None --  None
# 620439319 IDC-Ms ISC|IDC-Ms
# 620439338 NEIC-Mb ISC|NEIC-Mb
# 620440355 NIED-Mw ISC|NIED-Mw
# 620507393 NEIC-Mb ISC|NEIC-Mb
# 620509686 NEIC-Mb ISC|NEIC-Mb
# 620509696 IDC-Ms ISC|IDC-Ms
# 620509697 ISC-Ms ISC|ISC-Ms
# 620509702 ISC-Ms ISC|ISC-Ms
# 620509779 -- None --  None
# 620510520 ISC-Mb ISC|ISC-Mb
# 620508824 NIED-Mw ISC|NIED-Mw
# 620510548 IDC-Ms ISC|IDC-Ms
# 620444892 GCMT-Mw ISC|GCMT-Mw
# 620510560 NEIC-Mb ISC|NEIC-Mb
# 620445301 NEIC-Mb ISC|NEIC-Mb
# 620510592 ISC-Mb ISC|ISC-Mb
# 620445322 GCMT-Mw ISC|GCMT-Mw
# 620510598 IDC-Ms ISC|IDC-Ms
# 620445350 NIED-Mw ISC|NIED-Mw
# 620510616 -- None --  None
# 620510618 ISC-Mb ISC|ISC-Mb
# 620510644 ISC-Mb ISC|ISC-Mb
# 620510645 IDC-Ms IDC|IDC-Ms
# 620510647 IDC-Ms ISC|IDC-Ms
# 620511897 -- None --  None
# 620445797 IDC-Ms ISC|IDC-Ms
# 620489009 ISC-Ms ISC|ISC-Ms
# 620511926 NEIC-Mb ISC|NEIC-Mb
# 620508832 NIED-Mw ISC|NIED-Mw
# 620511933 NEIC-Mb ISC|NEIC-Mb
# 620511968 IDC-Ms IDC|IDC-Ms
# 620511975 IDC-Ms ISC|IDC-Ms
# 620448749 NEIC-Mb ISC|NEIC-Mb
# 620513280 ISC-Mb ISC|ISC-Mb
# 620513298 IDC-Ms ISC|IDC-Ms
# 620464976 IDC-Ms ISC|IDC-Ms
# 620513310 NEIC-Mb ISC|NEIC-Mb
# 620513327 NEIC-Mb ISC|NEIC-Mb
# 620513341 NEIC-Mb ISC|NEIC-Mb
# 620514628 -- None --  None
# 620514634 ISC-Mb ISC|ISC-Mb
# 620514651 IDC-Ms ISC|IDC-Ms
# 620514656 -- None --  None
# 620514666 ISC-Mb ISC|ISC-Mb
# 620489257 IDC-Ms ISC|IDC-Ms
# 620514707 ISC-Ms ISC|ISC-Ms
# 620518469 IDC-Ms IDC|IDC-Ms
# 620496816 GCMT-Mw ISC|GCMT-Mw
# 620496819 GCMT-Mw ISC|GCMT-Mw
# 620518479 NEIC-Mb ISC|NEIC-Mb
# 620518480 IDC-Ms ISC|IDC-Ms
# 620506188 IDC-Ms ISC|IDC-Ms
# 620518491 NEIC-Mb ISC|NEIC-Mb
# 620518540 ISC-Ms ISC|ISC-Ms
# 620518543 NEIC-Mb ISC|NEIC-Mb
# 620518573 ISC-Mb ISC|ISC-Mb
# 620527744 NEIC-Mb ISC|NEIC-Mb
# 620527784 NEIC-Mb ISC|NEIC-Mb
# 620527796 -- None --  None
# 620527797 -- None --  None
# 620507748 NEIC-Mb ISC|NEIC-Mb
# 620507749 GCMT-Mw ISC|GCMT-Mw
# 620507852 GCMT-Mw ISC|GCMT-Mw
# 620507855 GCMT-Mw ISC|GCMT-Mw
# 620531387 NEIC-Mb ISC|NEIC-Mb
# 620531389 ISC-Mb ISC|ISC-Mb
# 620531399 ISC-Mb ISC|ISC-Mb
# 620531405 IDC-Ms ISC|IDC-Ms
# 620507873 GCMT-Mw ISC|GCMT-Mw
# 620531408 NEIC-Mb ISC|NEIC-Mb
# 620531409 NEIC-Mb ISC|NEIC-Mb
# 620531410 ISC-Ms ISC|ISC-Ms
# 620507878 GCMT-Mw ISC|GCMT-Mw
# 620531411 NEIC-Mb ISC|NEIC-Mb
# 620507993 ISC-Ms ISC|ISC-Ms
# 620531420 ISC-Ms ISC|ISC-Ms
# 620531421 IDC-Ms ISC|IDC-Ms
# 620531423 IDC-Ms ISC|IDC-Ms
# 620531426 IDC-Ms ISC|IDC-Ms
# 620531429 IDC-Ms ISC|IDC-Ms
# 620531445 IDC-Ms ISC|IDC-Ms
# 620531447 IDC-Ms ISC|IDC-Ms
# 620531453 ISC-Ms ISC|ISC-Ms
# 620533818 IDC-Ms ISC|IDC-Ms
# 620533819 ISC-Mb ISC|ISC-Mb
# 620533831 IDC-Ms ISC|IDC-Ms
# 620533833 IDC-Ms ISC|IDC-Ms
# 620533841 IDC-Ms ISC|IDC-Ms
# 620533856 IDC-Ms ISC|IDC-Ms
# 620533859 IDC-Ms ISC|IDC-Ms
# 620508554 ISC-Ms ISC|ISC-Ms
# 620533870 IDC-Ms ISC|IDC-Ms
# 620533874 -- None --  None
# 620533878 ISC-Ms ISC|ISC-Ms
# 620533880 ISC-Mb ISC|ISC-Mb
# 620508870 GCMT-Mw ISC|GCMT-Mw
# 620533905 IDC-Ms ISC|IDC-Ms
# 620533916 ISC-Mb ISC|ISC-Mb
# 620533918 NEIC-Mb ISC|NEIC-Mb
# 620533919 ISC-Ms ISC|ISC-Ms
# 620533962 IDC-Ms ISC|IDC-Ms
# 620534747 NEIC-Mb ISC|NEIC-Mb
# 620509954 IDC-Ms ISC|IDC-Ms
# 620534772 IDC-Ms ISC|IDC-Ms
# 620534785 IDC-Ms ISC|IDC-Ms
# 620534786 -- None --  None
# 620510688 IDC-Ms ISC|IDC-Ms
# 620534789 IDC-Ms ISC|IDC-Ms
# 620534791 ISC-Mb ISC|ISC-Mb
# 620534793 ISC-Ms ISC|ISC-Ms
# 620511045 IDC-Ms ISC|IDC-Ms
# 620534804 ISC-Ms ISC|ISC-Ms
# 620511046 NIED-Mw ISC|NIED-Mw
# 620511053 GCMT-Mw ISC|GCMT-Mw
# 620538563 ISC-Ms ISC|ISC-Ms
# 620538585 ISC-Mb ISC|ISC-Mb
# 620538598 IDC-Ms ISC|IDC-Ms
# 620538602 IDC-Ms ISC|IDC-Ms
# 620512327 GCMT-Mw ISC|GCMT-Mw
# 620544711 ISC-Ms ISC|ISC-Ms
# 620512333 GCMT-Mw ISC|GCMT-Mw
# 625671767 NEIC-Mb ISC|NEIC-Mb
# 620512352 IDC-Ms ISC|IDC-Ms
# 625671819 IDC-Ms ISC|IDC-Ms
# 620513357 ISC-Mb ISC|ISC-Mb
# 620544747 ISC-Mb ISC|ISC-Mb
# 620513409 NEIC-Mb ISC|NEIC-Mb
# 620965644 NIED-Mw ISC|NIED-Mw
# 620544767 NEIC-Mb ISC|NEIC-Mb
# 620554816 ISC-Mb ISC|ISC-Mb
# 620554842 ISC-Mb ISC|ISC-Mb
# 620554844 IDC-Ms ISC|IDC-Ms
# 620554866 IDC-Ms ISC|IDC-Ms
# 620514132 ISC-Ms ISC|ISC-Ms
# 620514125 GCMT-Mw ISC|GCMT-Mw
# 620734413 NIED-Mw ISC|NIED-Mw
# 620554880 IDC-Ms ISC|IDC-Ms
# 620554885 IDC-Ms IDC|IDC-Ms
# 620554888 IDC-Ms ISC|IDC-Ms
# 620554893 NEIC-Mb ISC|NEIC-Mb
# 620554897 IDC-Ms ISC|IDC-Ms
# 620554916 IDC-Ms IDC|IDC-Ms
# 620562715 IDC-Ms ISC|IDC-Ms
# 620562716 NEIC-Mb ISC|NEIC-Mb
# 620562720 -- None --  None
# 620514776 GCMT-Mw ISC|GCMT-Mw
# 620562724 ISC-Mb ISC|ISC-Mb
# 620514779 NEIC-Mb ISC|NEIC-Mb
# 620562725 GCMT-Mw ISC|GCMT-Mw
# 620562727 NEIC-Mb ISC|NEIC-Mb
# 620562728 NEIC-Mb ISC|NEIC-Mb
# 620562729 ISC-Mb ISC|ISC-Mb
# 620562730 IDC-Ms ISC|IDC-Ms
# 620562731 ISC-Mb ISC|ISC-Mb
# 620562737 NEIC-Mb ISC|NEIC-Mb
# 620562752 IDC-Ms ISC|IDC-Ms
# 620562753 IDC-Ms ISC|IDC-Ms
# 620562754 NEIC-Mb ISC|NEIC-Mb
# 620562763 -- None --  None
# 620562765 IDC-Ms ISC|IDC-Ms
# 620562785 -- None --  None
# 620518583 NEIC-Mb ISC|NEIC-Mb
# 620562803 IDC-Ms ISC|IDC-Ms
# 620562810 ISC-Ms ISC|ISC-Ms
# 620562811 ISC-Mb ISC|ISC-Mb
# 620562820 ISC-Mb ISC|ISC-Mb
# 620572884 NEIC-Mb ISC|NEIC-Mb
# 620572886 IDC-Ms ISC|IDC-Ms
# 620572930 IDC-Ms ISC|IDC-Ms
# 620527920 ISC-Ms ISC|ISC-Ms
# 620527921 ISC-Ms ISC|ISC-Ms
# 620572941 ISC-Mb ISC|ISC-Mb
# 620582368 IDC-Ms ISC|IDC-Ms
# 620582393 IDC-Ms IDC|IDC-Ms
# 620582397 IDC-Ms ISC|IDC-Ms
# 620582407 ISC-Mb ISC|ISC-Mb
# 620650371 ISC-Mb ISC|ISC-Mb
# 620650373 ISC-Ms ISC|ISC-Ms
# 620650374 IDC-Ms ISC|IDC-Ms
# 620650413 IDC-Ms ISC|IDC-Ms
# 626080628 ISC-Mb ISC|ISC-Mb
# 620534072 IDC-Ms ISC|IDC-Ms
# 620534070 GCMT-Mw ISC|GCMT-Mw
# 620676412 IDC-Ms ISC|IDC-Ms
# 620676413 -- None --  None
# 620676423 -- None --  None
# 620676429 IDC-Ms ISC|IDC-Ms
# 620676445 IDC-Ms ISC|IDC-Ms
# 620534276 IDC-Ms ISC|IDC-Ms
# 620534283 IDC-Ms ISC|IDC-Ms
# 620676481 ISC-Ms ISC|ISC-Ms
# 620676484 IDC-Ms ISC|IDC-Ms
# 620534385 NIED-Mw ISC|NIED-Mw
# 620713933 NEIC-Mb ISC|NEIC-Mb
# 620713954 IDC-Ms IDC|IDC-Ms
# 620713979 ISC-Mb ISC|ISC-Mb
# 620713983 ISC-Mb ISC|ISC-Mb
# 620713984 NEIC-Mb ISC|NEIC-Mb
# 620714000 -- None --  None
# 620714028 IDC-Ms ISC|IDC-Ms
# 620714031 ISC-Mb ISC|ISC-Mb
# 620714033 ISC-Ms ISC|ISC-Ms
# 620714034 NEIC-Mb ISC|NEIC-Mb
# 620714050 IDC-Ms ISC|IDC-Ms
# 620734416 NIED-Mw NIED|NIED-Mw
# 620734123 NEIC-Mb ISC|NEIC-Mb
# 620734141 ISC-Ms ISC|ISC-Ms
# 620734163 ISC-Mb ISC|ISC-Mb
# 620754123 IDC-Ms ISC|IDC-Ms
# 620758618 IDC-Ms IDC|IDC-Ms
# 620560359 IDC-Ms ISC|IDC-Ms
# 620758653 ISC-Mb ISC|ISC-Mb
# 620758659 IDC-Ms ISC|IDC-Ms
# 620758668 ISC-Mb ISC|ISC-Mb
# 620758670 NEIC-Mb ISC|NEIC-Mb
# 620567645 NEIC-Mb ISC|NEIC-Mb
# 620567646 NEIC-Mb ISC|NEIC-Mb
# 620567769 IDC-Ms ISC|IDC-Ms
# 620779923 -- None --  None
# 620779927 IDC-Ms IDC|IDC-Ms
# 620779929 ISC-Ms ISC|ISC-Ms
# 620779930 -- None --  None
# 620779939 -- None --  None
# 620779942 -- None --  None
# 625560729 GCMT-Mw ISC|GCMT-Mw
# 620786231 NEIC-Mb ISC|NEIC-Mb
# 620786235 -- None --  None
# 620786236 IDC-Ms IDC|IDC-Ms
# 620786253 -- None --  None
# 620571054 NIED-Mw ISC|NIED-Mw
# 620786263 IDC-Ms ISC|IDC-Ms
# 620786272 IDC-Ms ISC|IDC-Ms
# 620786279 ISC-Ms ISC|ISC-Ms
# 620786292 ISC-Mb ISC|ISC-Mb
# 620786298 ISC-Mb ISC|ISC-Mb
# 620574417 GCMT-Mw ISC|GCMT-Mw
# 620582439 ISC-Ms ISC|ISC-Ms
# 620582444 ISC-Ms ISC|ISC-Ms
# 620582446 IDC-Ms ISC|IDC-Ms
# 620786324 NEIC-Mb ISC|NEIC-Mb
# 620786321 NEIC-Mb ISC|NEIC-Mb
# 620786340 NEIC-Mb ISC|NEIC-Mb
# 620587702 IDC-Ms ISC|IDC-Ms
# 620802559 IDC-Ms ISC|IDC-Ms
# 620802571 IDC-Ms ISC|IDC-Ms
# 620587931 IDC-Ms ISC|IDC-Ms
# 620802588 -- None --  None
# 620802596 IDC-Ms ISC|IDC-Ms
# 620802599 IDC-Ms ISC|IDC-Ms
# 620802602 ISC-Ms ISC|ISC-Ms

# %% [markdown]
# As logging was enabled, we can dump the log to a csv file and explore which rules and which hierarchy was applied for each event

# %%
from datetime import datetime

# Get the current date and time
current_datetime = datetime.now().strftime('%Y.%m.%d.%H.%M.%S')

log_file = f"outputs/1900-2021-isc-gem-rb-homogenisor_log_{current_datetime}.csv"
# log_file = f"outputs/1900-2021-isc-rb-homogenisor_log_{current_datetime}.csv"
if os.path.exists(log_file):
    os.remove(log_file)

harmonisor.dump_log(log_file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 11
#       8 if os.path.exists(log_file):
#       9     os.remove(log_file)
# ---> 11 harmonisor.dump_log(log_file)
#
# File ~\mbtk\oq-mbtk\openquake\cat\isc_homogenisor.py:729, in DynamicHomogenisor.dump_log(self, filename)
#     727 else:
#     728     magnitude_rule_idx = ""
# --> 729 if "," in event.description:
#     730     descriptor = event.description.replace(",", ";")
#     731 else:
#
# TypeError: argument of type 'NoneType' is not iterable

# %% [markdown]
# ### Export the Homogenised Catalogue to CSV

# %%
output_catalogue_file = f"outputs/1900-2021-isc-gem-rb-homogeneous_catalogue_{current_datetime}.csv"
# output_catalogue_file = f"outputs/1900-2021-isc-rb-homogeneous_catalogue_{current_datetime}.csv"
if os.path.exists(output_catalogue_file):
    os.remove(output_catalogue_file)
harmonisor.export_homogenised_to_csv(output_catalogue_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 output_catalogue_file = f"outputs/1900-2021-isc-gem-rb-homogeneous_catalogue_{current_datetime}.csv"
#       2 # output_catalogue_file = f"outputs/1900-2021-isc-rb-homogeneous_catalogue_{current_datetime}.csv"
#       3 if os.path.exists(output_catalogue_file):
#
# NameError: name 'current_datetime' is not defined

# %%
import os
import pandas as pd

# %%
csv_file_path = os.getcwd() + r'\inputs\datetime-test.csv'
csv_file_path
# Out:
# 'C:\\Users\\enrico.abcede\\mbtk\\oq-mbtk\\notebook\\datetime-test.csv'

# %%
# Replace 'your_file.csv' with the actual path to your CSV file.
csv_file_path = os.getcwd() + r'\inputs\datetime-weatherill.csv'

# Use read_csv() to read the CSV file and create a DataFrame.
df = pd.read_csv(csv_file_path)


# Create a pandas datetime object by combining the individual columns.
df['datetime'] = pd.to_datetime(df[['year', 'month', 'day', 'hour', 'minute', 'second']])

# Get the Unix timestamp and store it in a new column 'unix_timestamp'.
df['unix_weatherill-timestamp'] = df['datetime'].apply(lambda x: x.timestamp())

# Now you have a new column 'unix_timestamp' containing the Unix timestamps.
df

# Define the filename for the CSV file.
csv_file_outpath = os.getcwd() + r'\outputs'
csv_filename = "weatherill-unix.csv"

# Concatenate the current directory and the filename to get the full file path.
output_path = os.path.join(csv_file_outpath , csv_filename)

# Save the DataFrame as a CSV file in the specified output path.
df.to_csv(output_path, index=False)
