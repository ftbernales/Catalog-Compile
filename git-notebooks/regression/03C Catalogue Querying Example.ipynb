
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9520056)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9752796)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9388354)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9140169)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9752806)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:11123541)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9388357)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:11123542)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9388358)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9140208)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:11123554)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:11123555)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9140222)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:11123559)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9389192)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9140225)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9140227)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:11123563)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9140233)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9140240)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9140261)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9200945)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9389272)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9389317)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9389326)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9753150)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9201048)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9389396)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9753262)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9389438)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9140387)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9201091)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9753319)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9201096)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:11123603)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9140392)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9753321)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9201100)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9140397)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9201107)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:11123608)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:10472453)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:11123613)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9140415)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9389498)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9140426)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9753435)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:11123620)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9140440)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\Desktop\catalogue\oq-mbtk-repo\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:9201147)
#   warnings.warn(fmt.format(eq.id))

# %% [markdown]
# ## Using the Database

# %%
db1 = cqt.CatalogueDB(database_file)

# %% [markdown]
# ### Apply Limiting Selections

# %% [markdown]
# #### By Bounding Box

# %%
lower_lon = 15.
upper_lon = 30.
lower_lat = 30.
upper_lat = 45.
bbox = [lower_lon, upper_lon, lower_lat, upper_lat]
selector = cqt.CatalogueSelector(db1)
aegean_cat = selector.select_within_bounding_box(bbox)

# %%
number_origins, number_magnitudes = aegean_cat._get_number_origins_magnitudes()
print("Number of Origins = %d, Number of Magnitudes = %d" % (number_origins,
                                                             number_magnitudes))
# Out:
# Number of Origins = 2267, Number of Magnitudes = 4116

# %% [markdown]
# #### By Polygon

# %%
polygon = np.array([[15.0, 45.0],
                    [30.0, 45.0],
                    [30.0, 30.0],
                    [15.0, 30.0],
                    [15.0, 45.0]])
selector2 = cqt.CatalogueSelector(db1)
aegean_cat_alt = selector2.select_within_polygon(polygon[:, 0], polygon[:, 1])
number_origins, number_magnitudes = aegean_cat_alt._get_number_origins_magnitudes()
print("Number of Origins = %d, Number of Magnitudes = %d" % (number_origins,
                                                             number_magnitudes))
# Out:
# Number of Origins = 2267, Number of Magnitudes = 4116

# %% [markdown]
# #### By Magnitude

# %%
# Above magnitude 6.0
selector3 = cqt.CatalogueSelector(aegean_cat)
aegean_cat_m6 = selector3.select_within_magnitude_range(lower_mag=6.0, upper_mag=9.0)
number_origins, number_magnitudes = aegean_cat_m6._get_number_origins_magnitudes()
print("Number of Origins = %d, Number of Magnitudes = %d" % (number_origins,
                                                             number_magnitudes))
# Out:
# Number of Origins = 176, Number of Magnitudes = 287

# %% [markdown]
# #### By Depth

# %%
selector4 = cqt.CatalogueSelector(aegean_cat_alt)
aegean_cat_deep = selector4.select_within_depth_range(upper_depth=50.0, lower_depth=200.0)
number_origins, number_magnitudes = aegean_cat_deep._get_number_origins_magnitudes()
print("Number of Origins = %d, Number of Magnitudes = %d" % (number_origins,
                                                             number_magnitudes))
# Out:
# Number of Origins = 1021, Number of Magnitudes = 1845

# %% [markdown]
# ## Exploring the Catalogue Database

# %% [markdown]
# ### See Summary of Agencies and Magnitudes in the Catalogue

# %%
agency_count = cqt.get_agency_magtype_statistics(db1)
# Out:
# Agency: NEIC - 9444 Origins
# mb (9717) | MS (1930) | MW (819) | ME (327) | ML (2) | Mw (1) | MD (1)
# ========================================
# Agency: ISC - 9424 Origins
# mb (9400) | MS (6799)
# ========================================
# Agency: IDC - 9125 Origins
# mb (9122) | mb1 (9122) | mb1mx (9122) | mbtmp (9122) | MS (7365) | Ms1 (7365) | ms1mx (7365) | ML (5440)
# ========================================
# Agency: BJI - 8550 Origins
# mB (8341) | mb (7500) | Ms (6790) | Msz (6764) | ML (459)
# ========================================
# Agency: EHB - 8019 Origins
# No magnitudes corresponding to this agency
# ========================================
# Agency: MOS - 6964 Origins
# mb (6959) | MS (2246) | MW (28)
# ========================================
# Agency: ISCJB - 4550 Origins
# mb (4542) | MS (3174)
# ========================================
# Agency: HRVD - 3197 Origins
# MW (3204)
# ========================================
# Agency: SZGRF - 1476 Origins
# mb (1281) | MS (338) | ML (3)
# ========================================
# Agency: CSEM - 999 Origins
# mb (907) | Ms (227) | ML (136) | Mw (92) | MS (2) | MW (2) | MD (1)
# ========================================
# Agency: JMA - 742 Origins
# UK (739) | MG (2)
# ========================================
# Agency: NIED - 717 Origins
# Mw (717) | MW (341)
# ========================================
# Agency: MAN - 568 Origins
# ML (535) | mb (534) | MS (446)
# ========================================
# Agency: GCMT - 541 Origins
# MW (541)
# ========================================
# Agency: LDG - 487 Origins
# Mb (400) | Ms (292) | Ml (53) | ms (20) | Md (15) | ML (8)
# ========================================
# Agency: SKHL - 445 Origins
# mb (356) | msh (239) | Ms (202) | mbh (111) | ms (56) | mbv (35) | msha (15)
# ========================================
# Agency: CRAAG - 445 Origins
# Mb (368) | Mw (65) | Ml (10) | Ms (1) | MW (1)
# ========================================
# Agency: BGS - 426 Origins
# mb (348) | MS (34)
# ========================================
# Agency: NNC - 321 Origins
# mpv (276) | mb (113)
# ========================================
# Agency: GUC - 283 Origins
# ML (301) | MD (32) | mb (2)
# ========================================
# Agency: DJA - 226 Origins
# MD (104) | ML (93) | mb (66)
# ========================================
# Agency: CASC - 207 Origins
# MD (230) | ML (141) | MW (49) | mb (3) | MS (1)
# ========================================
# Agency: NAO - 206 Origins
# mb (172) | ML (51)
# ========================================
# Agency: KRSC - 170 Origins
# ML (170)
# ========================================
# Agency: NDI - 161 Origins
# ML (130) | mb (71) | MD (9) | MS (5) | MW (4)
# ========================================
# Agency: TEH - 130 Origins
# Mn (103) | MN (70) | ML (46)
# ========================================
# Agency: THR - 128 Origins
# ML (199) | MS (3) | mb (3) | MW (1)
# ========================================
# Agency: DHMR - 126 Origins
# ML (95) | mb (63) | MD (1)
# ========================================
# Agency: ATH - 125 Origins
# ML (194) | MD (114)
# ========================================
# Agency: THE - 124 Origins
# ML (169)
# ========================================
# Agency: ORF - 124 Origins
# mb (123) | ML (17)
# ========================================
# Agency: PDG - 119 Origins
# ML (31) | MD (27)
# ========================================
# Agency: ZUR_RMT - 113 Origins
# Mw (113)
# ========================================
# Agency: HLW - 107 Origins
# Mb (107) | ML (2)
# ========================================
# Agency: MEX - 98 Origins
# MD (173)
# ========================================
# Agency: IGIL - 94 Origins
# MS (65) | ML (23) | mb (9)
# ========================================
# Agency: TAP - 91 Origins
# ML (126)
# ========================================
# Agency: WEL - 83 Origins
# ML (125) | MG (13) | mb (1)
# ========================================
# Agency: MED_RCMT - 78 Origins
# MW (78)
# ========================================
# Agency: ISK - 73 Origins
# ML (105) | MD (25)
# ========================================
# Agency: SKO - 67 Origins
# ML (11) | M (8) | Mb (2) | MLg (1)
# ========================================
# Agency: OMAN - 66 Origins
# No magnitudes corresponding to this agency
# ========================================
# Agency: NIC - 60 Origins
# ML (62) | mb (46) | MW (40)
# ========================================
# Agency: TRN - 56 Origins
# MD (98)
# ========================================
# Agency: SFS - 52 Origins
# ML (38)
# ========================================
# Agency: PRE - 48 Origins
# ML (49)
# ========================================
# Agency: STR - 47 Origins
# Ml (27) | Mb (18) | Ms (12) | ML (6)
# ========================================
# Agency: PRU - 47 Origins
# M (40)
# ========================================
# Agency: IGQ - 47 Origins
# MD (43) | mb (35) | Mb (12) | Ms (12)
# ========================================
# Agency: MDD - 37 Origins
# mb (29) | mbLg (10) | MN (9) | MG (4)
# ========================================
# Agency: FUNV - 36 Origins
# MW (36)
# ========================================
# Agency: PGC - 35 Origins
# Mw (34) | MW (24) | ML (17) | MLSn (10)
# ========================================
# Agency: INMG - 33 Origins
# ML (29) | Mb (11) | MD (7) | MW (1)
# ========================================
# Agency: ROM - 30 Origins
# Ml (29) | ML (13) | Md (8) | MD (2) | MW (1)
# ========================================
# Agency: BER - 30 Origins
# ML (33) | MD (20) | mb (1) | MW (1)
# ========================================
# Agency: DMN - 29 Origins
# Ml (28) | ML (2) | Mb (1)
# ========================================
# Agency: GRAL - 28 Origins
# MD (28)
# ========================================
# Agency: CNRM - 27 Origins
# MD (27)
# ========================================
# Agency: SOF - 22 Origins
# MD (24)
# ========================================
# Agency: BYKL - 20 Origins
# MS (2)
# ========================================
# Agency: TIR - 19 Origins
# Ml (17)
# ========================================
# Agency: ECX - 19 Origins
# ML (23) | MD (16)
# ========================================
# Agency: SVSA - 18 Origins
# Mb (13) | ML (3) | MW (2)
# ========================================
# Agency: IASPEI - 17 Origins
# No magnitudes corresponding to this agency
# ========================================
# Agency: RSPR - 16 Origins
# MD (43) | ML (1) | MW (1)
# ========================================
# Agency: IPEC - 15 Origins
# ML (8)
# ========================================
# Agency: PDA - 15 Origins
# mb (11) | ML (4)
# ========================================
# Agency: TIF - 15 Origins
# No magnitudes corresponding to this agency
# ========================================
# Agency: NSSC - 12 Origins
# No magnitudes corresponding to this agency
# ========================================
# Agency: UPP - 11 Origins
# ML (3)
# ========================================
# Agency: GII - 11 Origins
# ML (13) | mb (9) | Mw (6)
# ========================================
# Agency: KNET - 10 Origins
# ml (10)
# ========================================
# Agency: SSNC - 8 Origins
# MD (8) | ML (8)
# ========================================
# Agency: BUC - 7 Origins
# ML (15) | MD (11)
# ========================================
# Agency: PLV - 7 Origins
# MD (4) | ML (3)
# ========================================
# Agency: HEL - 6 Origins
# ML (6)
# ========================================
# Agency: VIE - 6 Origins
# ML (5) | mb (5) | Ms (4)
# ========================================
# Agency: REY - 5 Origins
# ML (10)
# ========================================
# Agency: OTT - 5 Origins
# MN (4) | ML (3)
# ========================================
# Agency: JSN - 5 Origins
# MD (6)
# ========================================
# Agency: SNSN - 5 Origins
# Ml (2)
# ========================================
# Agency: NERS - 4 Origins
# MSH (3) | MPV (1)
# ========================================
# Agency: SSN - 4 Origins
# mb (4)
# ========================================
# Agency: BGR - 4 Origins
# ML (4)
# ========================================
# Agency: NSSP - 4 Origins
# ML (4)
# ========================================
# Agency: ZUR - 4 Origins
# mb (3) | ML (2)
# ========================================
# Agency: AUST - 3 Origins
# ML (6)
# ========================================
# Agency: BEO - 3 Origins
# No magnitudes corresponding to this agency
# ========================================
# Agency: WAR - 3 Origins
# ML (3)
# ========================================
# Agency: UAV - 2 Origins
# No magnitudes corresponding to this agency
# ========================================
# Agency: GCG - 2 Origins
# MD (2) | ML (1)
# ========================================
# Agency: UCR - 2 Origins
# ML (2) | MD (1) | MW (1)
# ========================================
# Agency: KISR - 2 Origins
# mb (4) | ML (2)
# ========================================
# Agency: PNSN - 1 Origins
# MD (1)
# ========================================
# Agency: LJU - 1 Origins
# ML (2)
# ========================================
# Agency: IAG - 1 Origins
# Mw (1)
# ========================================
# Agency: SSS - 1 Origins
# No magnitudes corresponding to this agency
# ========================================
# Agency: INET - 1 Origins
# MD (1)
# ========================================
# Agency: DUSS - 1 Origins
# ML (1)
# ========================================
# Agency: UPA - 1 Origins
# MD (1) | MW (1)
# ========================================
# Agency: GEN - 1 Origins
# ML (1)
# ========================================
# Agency: LEDBW - 1 Origins
# ML (1)
# ========================================
# Agency: BNS - 1 Origins
# ML (1)
# ========================================
# Agency: TUN - 1 Origins
# MD (1)
# ========================================

# %% [markdown]
# ### Search for a Specific Agency-Magnitude Combination

# %% [markdown]
# Search for body-wave magnitude common to 'BJI' and 'ISC'

# %%
query_bji_isc_mb, bji_isc_mb_cat = cqt.get_agency_magnitude_pairs(db1, ("BJI", "mb"), ("ISC", "mb"), no_case=True)
# Out:
# Agency-Pairs: (BJI, mb) & (ISC, mb) returned 8482 events

# %%
bji_isc_mb_cat

# %%
_ = cqt.plot_agency_magnitude_density(query_bji_isc_mb)

# %% [markdown]
# ### Join Query Results

# %% [markdown]
# Join together the results of two queries. For example the Global CMT magnitudes are reported under either
# 'GCMT' or 'HRVD'. So search for both terms

# %%
query1, cat1 = cqt.get_agency_magnitude_pairs(db1, ("BJI", "Ms"), ("GCMT", "Mw"), no_case=True)
query2, cat2 = cqt.get_agency_magnitude_pairs(db1, ("BJI", "Ms"), ("HRVD", "Mw"), no_case=True)
query_bji_gcmt_ms = cqt.join_query_results(query1, query2)
# Out:
# Agency-Pairs: (BJI, Ms) & (GCMT, Mw) returned 440 events
# Agency-Pairs: (BJI, Ms) & (HRVD, Mw) returned 2690 events

# %%
_ = cqt.plot_agency_magnitude_density(query_bji_gcmt_ms)

# %% [markdown]
# ## Regression Tools

# %% [markdown]
# In this example we compare the $M_S$ scale as recorded by the BJI network with the $M_W$ scale reported by
# HRVD/GCMT (from the previous query)

# %% [markdown]
# #### Set up the regression

# %%
regressor = cqt.CatalogueRegressor(query_bji_gcmt_ms)
regressor.plot_density(overlay=False)

# %% [markdown]
# #### Apply a Linear Model

# %%
linear_model = regressor.run_regression("polynomial", # Model Type
                                        [0., 1.]) # Initial guess of parameters
regressor.plot_model_density(False, 0)
# View Results
print("Mw = %.3f + %.3f MS +/- %.3f" % (regressor.results.beta[0],
                                        regressor.results.beta[1],
                                        regressor.standard_deviation))
# Out:
# Mw = 1.317 + 0.765 MS +/- 0.220

# %% [markdown]
# #### Overlay another model defined as a Magnitude Conversion Rule

# %%
from openquake.cat.isc_homogenisor import MagnitudeConversionRule
# Define empirical model
def RandomRule1(magnitude):
    return 1.21 + 0.84 * magnitude

def RandomRuleSigma(magnitude):
    return 0.2
# Create Rule
rule1 = MagnitudeConversionRule("BJI", "MS", RandomRule1, RandomRuleSigma,
                                model_name=r"$M_{W_{GCMT}} = 1.2 + 0.767 M_{S_{BJI}}$")
# Plot the model - with overla set to true
regressor.plot_model_density(True, 0)
# Overlay the rule and close the figure (overlay set to False)
regressor.plot_magnitude_conversion_model(rule1, False, line_color="b")

# %% [markdown]
# ### Apply a Piecewise Linear Model

# %%
initial_guess = [1.0, 1.0, 0.0]  # [slope 1, slope 2, intercept]

linear_model = regressor.run_regression("2segmentM6.1", # Model Type
                                        initial_guess) # Initial guess of parameters
regressor.plot_model_density(False, 0)
print("Standard Deviation - Segment 1: %.3f, Segment 2: %.3f" % (regressor.standard_deviation[0],
                                                                 regressor.standard_deviation[1]))
# Out:
# Standard Deviation - Segment 1: 0.212, Segment 2: 0.262
