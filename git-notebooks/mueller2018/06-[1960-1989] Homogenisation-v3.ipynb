# %%
# %matplotlib inline
import os
import numpy as np
import matplotlib.pyplot as plt

# Import the Parsers
from openquake.cat.parsers.isf_catalogue_reader import ISFReader
from openquake.cat.parsers.converters import (GenericCataloguetoISFParser, GCMTtoISFParser)
from openquake.cat.isc_homogenisor import (HomogenisorPreprocessor,
                                   DynamicHomogenisor,
                                   MagnitudeConversionRule,
                                   DuplicateFinder)
import openquake.cat.catalogue_query_tools as cqt

import unittest
import tempfile
import numpy as np
import pandas as pd
import toml

from openquake.cat.hmg import merge

import tempfile
import shutil

# %%
BASE_PATH = os.getcwd()
data_path = os.path.join(BASE_PATH, "inputs")

temp_dir = tempfile.mkdtemp()

# %%
# This merges multiple .isf files together

def append_isf_files(source_folder, output_file):
    '''  
    Append a series of .isf files that were downloaded from the ISC website.
    '''
    try:
        with open(output_file, 'w') as output:
            for filename in os.listdir(source_folder):
                if filename.endswith('.isf'):
                    file_path = os.path.join(source_folder, filename)
                    with open(file_path, 'r') as input_file:
                        content = input_file.read()
                        output.write(content + '\n')

        print("Content of text files appended together successfully.")
    except Exception as e:
        print("An error occurred:", str(e))

# Replace 'path_to_source_folder' with the actual path of the folder containing the text files.
source_folder = os.path.join(data_path, "isf")
output_file = os.path.join(BASE_PATH, "outputs", "1900-2021-PH_ISF_Catalogue.isf")


append_isf_files(source_folder, output_file)

# move to temp_dir
shutil.move(output_file, temp_dir)
print("moved to Temporary directory:", temp_dir)
# Out:
# Content of text files appended together successfully.
# moved to Temporary directory: C:\Users\ENRICO~1.ABC\AppData\Local\Temp\tmpm4vjhaz2

# %%
#ISCGEM
iscgem_parser = GenericCataloguetoISFParser("inputs/isc-gem-cat.csv")
iscgem_catalogue = iscgem_parser.parse("ISC-GEM", "ISC-GEM-CAT")

#ISC
isc_parser_1900_2021 = ISFReader(os.path.join(temp_dir, "1900-2021-PH_ISF_Catalogue.isf"),
                   selected_origin_agencies=["ISC-GEM", "ISC-EHB", "EHB", "ISC", "IDC", "NEIC", "NEIS", "USCGS", "NIED", "GCMT", "GUTE", "PAS"],
                   selected_magnitude_agencies=["ISC-GEM", "ISC-EHB", "EHB", "ISC", "IDC", "NEIC", "NEIS", "USCGS", "NIED", "GCMT", "GUTE", "PAS"])
isc_catalogue_1900_2021 = isc_parser_1900_2021.read_file("ISC-RB", "ISC-1900-2021")

#USGS-COMCAT
usgsComcat_parser = GenericCataloguetoISFParser("inputs/usgs1900-2023.csv")
usgsComcat_catalogue = usgsComcat_parser.parse("usgsComcat", "usgsComcat-CAT")

#GCMT
GCMT_catalogue = GCMTtoISFParser("inputs/gcmt-cat-1976-2020.txt").parse()

#Pacheco & Sykes 1992
PAS_parser = GenericCataloguetoISFParser("inputs/Pacheco-Sykes.csv")
PAS_catalogue = PAS_parser.parse("PAS", "PAS-CAT")

#PHIVOLCS
phivolcs_parser = GenericCataloguetoISFParser("inputs/phivolcs-combined-hmtk-minM4pt5.csv")
phivolcs_catalogue = phivolcs_parser.parse("phivolcs", "phivolcs-CAT")

print("ISC-GEM Catalogue 1900-2020 contains: %d events" % iscgem_catalogue.get_number_events())
print("ISC Reviewed Bulleting Catalogue 1900-2021 contains: %d events" % isc_catalogue_1900_2021.get_number_events())
print("USGS Catalogue 1977-2023 contains: %d events" % usgsComcat_catalogue.get_number_events())
print("GCMT Catalogue 1976-2020 contains: %d events" % GCMT_catalogue.get_number_events())
print("PAS Catalogue 1907-1943 contains: %d events" % PAS_catalogue.get_number_events())
print("PHIVOLCS Catalogue 2015-2023 contains: %d events" % phivolcs_catalogue.get_number_events())
# Out:
# Parsing catalogue ...
# complete. Contains 56832 moment tensors
# ISC-GEM Catalogue 1900-2020 contains: 3993 events
# ISC Reviewed Bulleting Catalogue 1900-2021 contains: 68488 events
# USGS Catalogue 1977-2023 contains: 30639 events
# GCMT Catalogue 1976-2020 contains: 56832 events
# PAS Catalogue 1907-1943 contains: 82 events
# PHIVOLCS Catalogue 2015-2023 contains: 1861 events

# %%
# Build the HDF5 Database
database_file_iscgem = os.path.join(temp_dir, "iscgem-catalogue_db.hdf5")
if os.path.exists(database_file_iscgem):
    os.remove(database_file_iscgem)
_ = iscgem_catalogue.build_dataframe(hdf5_file=database_file_iscgem)

db = cqt.CatalogueDB(database_file_iscgem)
agency_count = cqt.get_agency_magtype_statistics(db)
# Out:
# Agency: ISC-GEM - 3993 Origins
# Mw (3993)
# ========================================

# %%
# Build the HDF5 Database
database_file_iscrb = os.path.join(temp_dir, "iscrb-catalogue_db1.hdf5")
if os.path.exists(database_file_iscrb):
    os.remove(database_file_iscrb)
_ = isc_catalogue_1900_2021.build_dataframe(hdf5_file=database_file_iscrb)

db1 = cqt.CatalogueDB(database_file_iscrb)
agency_count = cqt.get_agency_magtype_statistics(db1)
# Out:
# Agency: ISC - 52964 Origins
# mb (50053) | MS (10086)
# ========================================
# Agency: IDC - 50238 Origins
# mb (50235) | mbtmp (42280) | mb1 (35182) | mb1mx (35164) | MS (20385) | Ms1 (13683) | ms1mx (13664) | ML (11085)
# ========================================
# Agency: NEIC - 31889 Origins
# mb (29044) | MSZ (1281) | MS (856) | MW (444) | Mww (444) | Mwb (194) | mw (169) | Ms_20 (156) | Mwr (115) | ME (114) | Mw (46) | Me (19) | Mwc (17) | ML (5) | mb_Lg (1)
# ========================================
# Agency: ISC-EHB - 16591 Origins
# No magnitudes corresponding to this agency
# ========================================
# Agency: EHB - 13380 Origins
# No magnitudes corresponding to this agency
# ========================================
# Agency: NEIS - 4118 Origins
# mb (4075) | MSZ (280) | MS (257) | mw (26) | Mb (1)
# ========================================
# Agency: GCMT - 3716 Origins
# MW (3703) | MS (13)
# ========================================
# Agency: NIED - 2108 Origins
# Mw (1469) | MW (638)
# ========================================
# Agency: USCGS - 1464 Origins
# mb (1444) | MS (69)
# ========================================
# Agency: GUTE - 214 Origins
# UK (74)
# ========================================

# %%
# Build the HDF5 Database
database_file_usgs = os.path.join(temp_dir, "usgs-catalogue_db2.hdf5")
if os.path.exists(database_file_usgs):
    os.remove(database_file_usgs)
_ = usgsComcat_catalogue.build_dataframe(hdf5_file=database_file_usgs)

db2 = cqt.CatalogueDB(database_file_usgs)
agency_count = cqt.get_agency_magtype_statistics(db2)
# Out:
# Agency: usgsComcat - 30639 Origins
# mb (27501) | mwc (1180) | mww (595) | mw (583) | ms (194) | mwr (176) | mwb (159) | m (135) | ml (115) | Mb (1)
# ========================================

# %%
# Build the HDF5 Database
database_file_gcmt = os.path.join(temp_dir, "gcmt-catalogue_db3.hdf5")
if os.path.exists(database_file_gcmt):
    os.remove(database_file_gcmt)
_ = GCMT_catalogue.build_dataframe(hdf5_file=database_file_gcmt)

db3 = cqt.CatalogueDB(database_file_gcmt)
agency_count = cqt.get_agency_magtype_statistics(db3)
# Out:
# Agency: GCMT - 56832 Origins
# Mw (56832)
# ========================================
# Agency: PDEW - 30674 Origins
# Ms (22489) | mb (14423)
# ========================================
# Agency: PDE  - 21841 Origins
# mb (21826) | Ms (13506)
# ========================================
# Agency: MLI  - 3065 Origins
# mb (3065) | Ms (1850)
# ========================================
# Agency: SWEQ - 1143 Origins
# Ms (1143)
# ========================================
# Agency: REB  - 57 Origins
# mb (55) | Ms (2)
# ========================================
# Agency: PDEQ - 33 Origins
# Ms (33)
# ========================================
# Agency: SWEM - 7 Origins
# Ms (7)
# ========================================
# Agency:      - 5 Origins
# mb (4) | Ms (4)
# ========================================
# Agency: HSW  - 4 Origins
# Ms (4)
# ========================================
# Agency: MLE  - 1 Origins
# mb (1) | Ms (1)
# ========================================
# Agency: ISC  - 1 Origins
# mb (1)
# ========================================
# Agency: DMC  - 1 Origins
# mb (1) | Ms (1)
# ========================================

# %%
# Build the HDF5 Database
database_file_PAS = os.path.join(temp_dir, "PAS-catalogue_db4.hdf5")
if os.path.exists(database_file_PAS):
    os.remove(database_file_PAS)
_ = PAS_catalogue.build_dataframe(hdf5_file=database_file_PAS)

db4 = cqt.CatalogueDB(database_file_PAS)
agency_count = cqt.get_agency_magtype_statistics(db4)
# Out:
# Agency: PAS - 82 Origins
# Mw (82)
# ========================================

# %%
# Build the HDF5 Database
database_file_Phivolcs = os.path.join(temp_dir, "phivolcs-catalogue_db4.hdf5")
if os.path.exists(database_file_Phivolcs):
    os.remove(database_file_Phivolcs)
_ = phivolcs_catalogue.build_dataframe(database_file_Phivolcs)

db4 = cqt.CatalogueDB(database_file_Phivolcs)
agency_count = cqt.get_agency_magtype_statistics(db4)
# Out:
# Agency: phivolcs - 1861 Origins
# Ms (1369) | Mw (479) | ML (6) | MLv (5) | Mwp (1) | mb (1)
# ========================================

# %%
time_window = 20
distance_window = 50

print('merging ISC-RB and usgs-comcat')
merge1 = DuplicateFinder(isc_catalogue_1900_2021, time_window, distance_window, logging=True)
merged1Catalogue = merge1.merge_catalogue(usgsComcat_catalogue)

print('merging gcmt')
merge2 = DuplicateFinder(merged1Catalogue, time_window, distance_window, logging=True)
merged2Catalogue = merge2.merge_catalogue(GCMT_catalogue)

print('merging PAS')
merge3 = DuplicateFinder(merged2Catalogue, time_window, distance_window, logging=True)
merged3Catalogue = merge3.merge_catalogue(PAS_catalogue)

print('merging phivolcs')
merge4 = DuplicateFinder(merged3Catalogue, time_window, distance_window, logging=True)
merged4Catalogue = merge4.merge_catalogue(phivolcs_catalogue)

print('merge to ISCGEM')
merge5 = DuplicateFinder(iscgem_catalogue, time_window, distance_window, logging=True)
merged5Catalogue = merge5.merge_catalogue(merged4Catalogue)

merged5Catalogue
# Out:
# merging ISC-RB and usgs-comcat
# After duplicate finding: 71299 events (71299)
# merging gcmt
# After duplicate finding: 124496 events (124496)
# merging PAS
# After duplicate finding: 124496 events (124496)
# merging phivolcs
# After duplicate finding: 124948 events (124948)
# merge to ISCGEM
# After duplicate finding: 125320 events (125320)

# %%
# Build the HDF5 Database
database_file = os.path.join(temp_dir, "merged-catalogue_db1.hdf5")
if os.path.exists(database_file):
    os.remove(database_file)
_ = merged5Catalogue.build_dataframe(hdf5_file=database_file)

db1 = cqt.CatalogueDB(database_file)
agency_count = cqt.get_agency_magtype_statistics(db1)
# Out:
# Agency: GCMT - 60548 Origins
# Mw (56832) | MW (3703) | MS (13)
# ========================================
# Agency: ISC - 52964 Origins
# mb (50053) | MS (10086)
# ========================================
# Agency: IDC - 50238 Origins
# mb (50235) | mbtmp (42280) | mb1 (35182) | mb1mx (35164) | MS (20385) | Ms1 (13683) | ms1mx (13664) | ML (11085)
# ========================================
# Agency: NEIC - 31889 Origins
# mb (29044) | MSZ (1281) | MS (856) | MW (444) | Mww (444) | Mwb (194) | mw (169) | Ms_20 (156) | Mwr (115) | ME (114) | Mw (46) | Me (19) | Mwc (17) | ML (5) | mb_Lg (1)
# ========================================
# Agency: PDEW - 30674 Origins
# Ms (22489) | mb (14423)
# ========================================
# Agency: usgsComcat - 30639 Origins
# mb (27501) | mwc (1180) | mww (595) | mw (583) | ms (194) | mwr (176) | mwb (159) | m (135) | ml (115) | Mb (1)
# ========================================
# Agency: PDE  - 21841 Origins
# mb (21826) | Ms (13506)
# ========================================
# Agency: ISC-EHB - 16591 Origins
# No magnitudes corresponding to this agency
# ========================================
# Agency: EHB - 13380 Origins
# No magnitudes corresponding to this agency
# ========================================
# Agency: NEIS - 4118 Origins
# mb (4075) | MSZ (280) | MS (257) | mw (26) | Mb (1)
# ========================================
# Agency: ISC-GEM - 3993 Origins
# Mw (3993)
# ========================================
# Agency: MLI  - 3065 Origins
# mb (3065) | Ms (1850)
# ========================================
# Agency: NIED - 2108 Origins
# Mw (1469) | MW (638)
# ========================================
# Agency: phivolcs - 1861 Origins
# Ms (1369) | Mw (479) | ML (6) | MLv (5) | mb (1) | Mwp (1)
# ========================================
# Agency: USCGS - 1464 Origins
# mb (1444) | MS (69)
# ========================================
# Agency: SWEQ - 1143 Origins
# Ms (1143)
# ========================================
# Agency: GUTE - 214 Origins
# UK (31)
# ========================================
# Agency: PAS - 82 Origins
# MS (214) | Mw (82) | UK (20) | Ms (4)
# ========================================
# Agency: REB  - 57 Origins
# mb (55) | Ms (2)
# ========================================
# Agency: PDEQ - 33 Origins
# Ms (33)
# ========================================
# Agency: SWEM - 7 Origins
# Ms (7)
# ========================================
# Agency:      - 5 Origins
# mb (4) | Ms (4)
# ========================================
# Agency: HSW  - 4 Origins
# Ms (4)
# ========================================
# Agency: DMC  - 1 Origins
# mb (1) | Ms (1)
# ========================================
# Agency: MLE  - 1 Origins
# mb (1) | Ms (1)
# ========================================
# Agency: ISC  - 1 Origins
# mb (1)
# ========================================

# %%
origin_rules = [
    ("1960/01/01 - 1989/12/31", ["ISC-GEM", "ISC-EHB", "EHB", "ISC", "ISC ", "IDC", "NEIC", "NEIS", "USCGS", "NIED", "GCMT", "GUTE", "PAS", "usgsComcat", "phivolcs"])
]

# %%
"""
Weatherill (2015) Table 1. Mw conversions
"""
def iscgem_mw(magnitude):
    """
    For Mw recorded by ISCGEM take the value with no uncertainty
    """
    return magnitude

def iscgem_mw_sigma(magnitude):
    """
    No additional uncertainty   
    """
    return 0.0

def gcmt_mw(magnitude):
    """
    For Mw recorded by GCMT take the value with no uncertainty
    """
    return magnitude

def gcmt_mw_sigma(magnitude):
    """
    No additional uncertainty   
    """
    return 0.0

def neic_mw(magnitude):
    """
    If Mw reported by NEIC,
    """
    return 1.021 * magnitude - 0.091

def neic_mw_sigma(magnitude):
    """
    Uncertainty of 0.101 units
    """
    return 0.105

def nied_mw(magnitude):
    """
    If Mw reported by NIED,
    """
    return 0.964 * magnitude + 0.248

def nied_mw_sigma(magnitude):
    """
    Uncertainty of 0.11 units
    """
    return 0.11

def isc_ms(magnitude):
    """
    If Ms reported by ISC, convert to Mw from Weatherill (2015),
    """
    if magnitude > 6.0:
        return 0.994 * magnitude + 0.1        
    else:
        return 0.616 * magnitude + 2.369

def isc_ms_sigma(magnitude):
    """
    With Magnitude dependent uncertainty
    """
    if magnitude > 6.0:
        return 0.174
    else:
        return 0.147

def neic_ms(magnitude):
    """
    If Ms reported by NEIC, convert to Mw from Weatherill (2015),
    """
    if magnitude > 6.47:
        return 1.005 * magnitude - 0.026       
    else:
        return 0.723 * magnitude + 1.798

def neic_ms_sigma(magnitude):
    """
    With Magnitude dependent uncertainty
    """
    if magnitude > 6.47:
        return 0.187
    else:
        return 0.159
    
def neic_msz(magnitude):
    """
    If Msz reported by NEIC, convert to Mw from Weatherill (2015),
    """
    if magnitude > 6.47:
        return 0.950 * magnitude + 0.359     
    else:
        return 0.707 * magnitude + 1.933

def neic_msz_sigma(magnitude):
    """
    With Magnitude dependent uncertainty
    """
    if magnitude > 6.47:
        return 0.204
    else:
        return 0.179

def neic_mb(magnitude):
    """
    If Mb reported by NEIC,
    """
    return 1.159 * magnitude - 0.659

def neic_mb_sigma(magnitude):
    """
    Uncertainty of 0.283 units
    """
    return 0.283

def isc_mb(magnitude):
    """
    If Mw reported by isc,
    """
    return 1.084 * magnitude - 0.142

def isc_mb_sigma(magnitude):
    """
    Uncertainty of 0.317 units
    """
    return 0.317

def pas_ms(magnitude):
    """
    For Ms recorded by paS take the value with no uncertainty. 
    In their database Pacheco & Sykes (1992) use
    the 20-s period Ms value, which, for our purposes, we treat as
    equivalent to MW in the magnitude range 7.0 ≤ MW ≤ 8.0. (Weatherill, 2015)
    """
    return magnitude

def pas_ms_sigma(magnitude):
    """
    0.2 additional uncertainty   
    """
    return 0.2

def phivolcs_ms(magnitude):
    """
    own regression
    """
    if magnitude > 6.5:
        return 0.686 * magnitude + 1.997     
    else:
        return 0.857 * magnitude + 0.888

def phivolcs_ms_sigma(magnitude):
    """
    own regression
    """
    if magnitude > 6.5:
        return 0.072
    else:
        return 0.185

def phivolcs_mw(magnitude):
    """
    own regression
    """
    if magnitude > 6.5:
        return 1.072 * magnitude - 0.562     
    else:
        return 0.887 * magnitude + 0.640

def phivolcs_mw_sigma(magnitude):
    """
    own regression
    """
    if magnitude > 6.5:
        return 0.114
    else:
        return 0.116

# %%
rule_set_1960_1989 = [
    MagnitudeConversionRule("ISC-GEM", "Mw", iscgem_mw, iscgem_mw_sigma),

    MagnitudeConversionRule("GCMT", "Mw", gcmt_mw, gcmt_mw_sigma),

    MagnitudeConversionRule("NEIC", "Mw", neic_mw, neic_mw_sigma),
    MagnitudeConversionRule("NEIS", "Mw", neic_mw, neic_mw_sigma),

    MagnitudeConversionRule("NIED", "Mw", nied_mw, nied_mw_sigma),

    MagnitudeConversionRule("ISC", "Ms", isc_ms, isc_ms_sigma),
    MagnitudeConversionRule("IDC", "Ms", isc_ms, isc_ms_sigma),

    MagnitudeConversionRule("NEIC", "Ms", neic_ms, neic_ms_sigma),
    MagnitudeConversionRule("NEIS", "MS", neic_ms, neic_ms_sigma),
    MagnitudeConversionRule("USCGS", "ms", neic_ms, neic_ms_sigma),
    

    MagnitudeConversionRule("NEIC", "Msz", neic_msz, neic_msz_sigma),
    MagnitudeConversionRule("NEIS", "Msz", neic_msz, neic_msz_sigma),

    MagnitudeConversionRule("NEIC", "Mb", neic_mb, neic_mb_sigma),
    MagnitudeConversionRule("NEIS", "Mb", neic_mb, neic_mb_sigma),
    MagnitudeConversionRule("USCGS", "mb", neic_mb, neic_mb_sigma),


    MagnitudeConversionRule("ISC", "Mb", isc_mb, isc_mb_sigma),
    
    MagnitudeConversionRule("PAS", "Ms", pas_ms, pas_ms_sigma),

    MagnitudeConversionRule("usgsComcat", "mwc", neic_mw, neic_mw_sigma),
    MagnitudeConversionRule("usgsComcat", "mww", neic_mw, neic_mw_sigma),
    MagnitudeConversionRule("usgsComcat", "mw", neic_mw, neic_mw_sigma),
    MagnitudeConversionRule("usgsComcat", "mwr", neic_mw, neic_mw_sigma),
    MagnitudeConversionRule("usgsComcat", "mwb", neic_mw, neic_mw_sigma),
    MagnitudeConversionRule("usgsComcat", "ms", neic_ms, neic_ms_sigma),
    MagnitudeConversionRule("usgsComcat", "mb", neic_mb, neic_mb_sigma),

    MagnitudeConversionRule("phivolcs", "Mw", phivolcs_mw, phivolcs_mw_sigma),
    MagnitudeConversionRule("phivolcs", "Ms", phivolcs_ms, phivolcs_ms_sigma),

]

magnitude_rules = [
    ("1960/01/01 - 1989/12/31", rule_set_1960_1989)
]

# %%
preprocessor = HomogenisorPreprocessor("time")
pp_catalogue = preprocessor.execute(merged5Catalogue, origin_rules, magnitude_rules)
harmonisor_1960_1989 = DynamicHomogenisor(pp_catalogue, logging=True)
homogenised_catalogue_1960_1989 = harmonisor_1960_1989.homogenise(magnitude_rules, origin_rules)
print("Merged Catalogue 1960-1989 contains: %d events" % homogenised_catalogue_1960_1989.get_number_events())
# Out:
# 877990 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 879799 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 880323 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 880356 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 880993 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 881019 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 876599 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 17290472 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 876974 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 876979 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 17291103 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 874313 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 874348 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 17291518 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 17292081 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 875035 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 875037 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 875110 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 17292251 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 871735 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 17293446 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 872024 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 17293721 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 17293778 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 872470 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 17293847 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 872542 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 873848 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 871050 USCGS-mb ISC-EHB|USCGS-mb
# 871256 USCGS-mb ISC|USCGS-mb
# 871334 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 871336 USCGS-mb ISC|USCGS-mb
# 871340 USCGS-mb ISC|USCGS-mb
# 871343 USCGS-mb ISC|USCGS-mb
# 871372 USCGS-mb ISC|USCGS-mb
# 871381 USCGS-mb EHB|USCGS-mb
# 871396 USCGS-mb ISC-EHB|USCGS-mb
# 871405 USCGS-mb ISC|USCGS-mb
# 871413 USCGS-mb ISC-EHB|USCGS-mb
# 871430 USCGS-mb ISC-EHB|USCGS-mb
# 871447 USCGS-mb ISC|USCGS-mb
# 871473 USCGS-mb ISC-EHB|USCGS-mb
# 791233 ISC-Mb ISC|ISC-Mb
# 791241 USCGS-mb ISC-EHB|USCGS-mb
# 791276 USCGS-mb EHB|USCGS-mb
# 791340 USCGS-mb EHB|USCGS-mb
# 791379 USCGS-mb ISC|USCGS-mb
# 791397 ISC-Mb ISC|ISC-Mb
# 791443 USCGS-mb ISC-EHB|USCGS-mb
# 791452 USCGS-mb ISC-EHB|USCGS-mb
# 791484 USCGS-mb ISC-EHB|USCGS-mb
# 789735 USCGS-mb ISC|USCGS-mb
# 789840 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 789887 USCGS-mb ISC-EHB|USCGS-mb
# 789983 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 789999 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 790022 USCGS-ms ISC-EHB|USCGS-ms
# 790029 USCGS-mb ISC|USCGS-mb
# 790053 USCGS-mb ISC-EHB|USCGS-mb
# 790056 USCGS-mb ISC-EHB|USCGS-mb
# 790168 USCGS-mb EHB|USCGS-mb
# 790180 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# ...
# GCMT_008145 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008146 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008147 GCMT-Mw GCMT|GCMT-Mw
# 395536 NEIC-Mb ISC|NEIC-Mb
# 395538 ISC-Ms ISC-EHB|ISC-Ms
# 395540 NEIC-Mb ISC|NEIC-Mb
# GCMT_008148 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008149 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008150 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008151 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008152 GCMT-Mw GCMT|GCMT-Mw
# 395606 NEIC-Mb ISC|NEIC-Mb
# GCMT_008153 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008154 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008155 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008156 GCMT-Mw GCMT|GCMT-Mw
# 395688 ISC-Ms ISC-EHB|ISC-Ms
# GCMT_008157 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008158 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008159 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008160 GCMT-Mw GCMT|GCMT-Mw
# 395776 NEIC-Mb EHB|NEIC-Mb
# 395778 NEIC-Mb ISC|NEIC-Mb
# 395806 ISC-Ms ISC-EHB|ISC-Ms
# GCMT_008161 GCMT-Mw GCMT|GCMT-Mw
# 395903 NEIC-Mb ISC|NEIC-Mb
# GCMT_008162 GCMT-Mw GCMT|GCMT-Mw
# 396004 NEIC-Mb ISC|NEIC-Mb
# 396082 NEIC-Mb ISC|NEIC-Mb
# GCMT_008163 GCMT-Mw GCMT|GCMT-Mw
# 396145 NEIC-Mb ISC|NEIC-Mb
# GCMT_008164 GCMT-Mw GCMT|GCMT-Mw
# 396277 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008165 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008166 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008167 GCMT-Mw GCMT|GCMT-Mw
# 396385 NEIC-Mb ISC|NEIC-Mb
# GCMT_008168 GCMT-Mw GCMT|GCMT-Mw
# 396426 NEIC-Mb ISC|NEIC-Mb
# 396444 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 396478 ISC-Ms ISC-EHB|ISC-Ms
# GCMT_008170 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008171 GCMT-Mw GCMT|GCMT-Mw
# 391446 NEIC-Mb EHB|NEIC-Mb
# 391459 ISC-Ms ISC-EHB|ISC-Ms
# GCMT_008172 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008173 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008174 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008175 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008176 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008177 GCMT-Mw GCMT|GCMT-Mw
# 391652 ISC-Ms ISC-EHB|ISC-Ms
# GCMT_008178 GCMT-Mw GCMT|GCMT-Mw
# 391682 ISC-Ms EHB|ISC-Ms
# 391704 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# GCMT_008180 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008181 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008182 GCMT-Mw GCMT|GCMT-Mw
# 391727 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008183 GCMT-Mw GCMT|GCMT-Mw
# 391738 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008184 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008185 GCMT-Mw GCMT|GCMT-Mw
# 391790 NEIC-Mb ISC|NEIC-Mb
# 391799 NEIC-Mb ISC|NEIC-Mb
# GCMT_008186 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008187 GCMT-Mw GCMT|GCMT-Mw
# 391829 NEIC-Ms EHB|NEIC-Ms
# 391833 GCMT-Mw ISC-EHB|GCMT-Mw
# 391871 ISC-Ms ISC-EHB|ISC-Ms
# 391874 ISC-Ms ISC-EHB|ISC-Ms
# GCMT_008189 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008190 GCMT-Mw GCMT|GCMT-Mw
# 391922 NEIC-Mb ISC|NEIC-Mb
# 391947 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008191 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008192 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008193 GCMT-Mw GCMT|GCMT-Mw
# 392007 NEIC-Mb ISC|NEIC-Mb
# 392026 NEIC-Mb ISC|NEIC-Mb
# GCMT_008194 GCMT-Mw GCMT|GCMT-Mw
# 392064 NEIC-Mb ISC|NEIC-Mb
# GCMT_008195 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008196 GCMT-Mw GCMT|GCMT-Mw
# 392297 ISC-Ms ISC-EHB|ISC-Ms
# GCMT_008197 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008198 GCMT-Mw GCMT|GCMT-Mw
# 392409 NEIC-Ms EHB|NEIC-Ms
# GCMT_008199 GCMT-Mw GCMT|GCMT-Mw
# 392468 GCMT-Mw ISC-EHB|GCMT-Mw
# GCMT_008201 GCMT-Mw GCMT|GCMT-Mw
# 392534 NEIC-Mb ISC-EHB|NEIC-Mb
# 392538 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 392540 NEIC-Mb ISC|NEIC-Mb
# 392542 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008203 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008204 GCMT-Mw GCMT|GCMT-Mw
# 392552 NEIC-Ms ISC-EHB|NEIC-Ms
# 392555 NEIC-Mb ISC|NEIC-Mb
# 392563 NEIC-Ms ISC|NEIC-Ms
# 392583 NEIC-Mb ISC|NEIC-Mb
# GCMT_008205 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008206 GCMT-Mw GCMT|GCMT-Mw
# 392617 ISC-Ms ISC-EHB|ISC-Ms
# 392663 NEIC-Ms ISC|NEIC-Ms
# GCMT_008207 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008208 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008209 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008210 GCMT-Mw GCMT|GCMT-Mw
# 392775 NEIC-Mb ISC|NEIC-Mb
# GCMT_008211 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008212 GCMT-Mw GCMT|GCMT-Mw
# 392879 NEIC-Mb ISC|NEIC-Mb
# GCMT_008213 GCMT-Mw GCMT|GCMT-Mw
# 392925 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008214 GCMT-Mw GCMT|GCMT-Mw
# 392986 NEIC-Mb EHB|NEIC-Mb
# GCMT_008215 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008216 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008217 GCMT-Mw GCMT|GCMT-Mw
# 393148 NEIC-Mb ISC|NEIC-Mb
# GCMT_008218 GCMT-Mw GCMT|GCMT-Mw
# 393207 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 393259 NEIC-Ms ISC-EHB|NEIC-Ms
# GCMT_008220 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008221 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008222 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008223 GCMT-Mw GCMT|GCMT-Mw
# 393439 NEIC-Mb EHB|NEIC-Mb
# GCMT_008224 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008225 GCMT-Mw GCMT|GCMT-Mw
# 393718 ISC-Mb ISC|ISC-Mb
# GCMT_008226 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008227 GCMT-Mw GCMT|GCMT-Mw
# 393827 NEIC-Ms ISC-EHB|NEIC-Ms
# GCMT_008228 GCMT-Mw GCMT|GCMT-Mw
# 388525 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# GCMT_008230 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008231 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008232 GCMT-Mw GCMT|GCMT-Mw
# 388676 NEIC-Mb ISC|NEIC-Mb
# GCMT_008233 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008234 GCMT-Mw GCMT|GCMT-Mw
# 388892 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008235 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008236 GCMT-Mw GCMT|GCMT-Mw
# 388918 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# GCMT_008238 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008239 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008240 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008241 GCMT-Mw GCMT|GCMT-Mw
# 389009 NEIC-Mb ISC|NEIC-Mb
# 389026 ISC-Mb ISC|ISC-Mb
# 389028 NEIC-Mb EHB|NEIC-Mb
# 389037 NEIC-Ms ISC|NEIC-Ms
# GCMT_008242 GCMT-Mw GCMT|GCMT-Mw
# 389047 NEIC-Mb ISC|NEIC-Mb
# GCMT_008243 GCMT-Mw GCMT|GCMT-Mw
# 389096 ISC-Mb ISC|ISC-Mb
# 389103 NEIC-Mb ISC|NEIC-Mb
# GCMT_008244 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008245 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008246 GCMT-Mw GCMT|GCMT-Mw
# 389250 NEIC-Ms ISC-EHB|NEIC-Ms
# 389257 NEIC-Mb ISC|NEIC-Mb
# usp00040ka -- None --  None
# 389315 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008247 GCMT-Mw GCMT|GCMT-Mw
# 389429 NEIC-Mb ISC|NEIC-Mb
# GCMT_008248 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008249 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008250 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008251 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008252 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008253 GCMT-Mw GCMT|GCMT-Mw
# 389646 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# GCMT_008255 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008256 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008257 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008258 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008259 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008260 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008261 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008262 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008263 GCMT-Mw GCMT|GCMT-Mw
# 389965 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008264 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008265 GCMT-Mw GCMT|GCMT-Mw
# 389976 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 389986 NEIC-Mb ISC|NEIC-Mb
# 390042 NEIC-Mb ISC|NEIC-Mb
# GCMT_008267 GCMT-Mw GCMT|GCMT-Mw
# 390090 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# GCMT_008269 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008270 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008271 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008272 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008273 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008274 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008275 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008276 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008277 GCMT-Mw GCMT|GCMT-Mw
# 390403 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008278 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008279 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008280 GCMT-Mw GCMT|GCMT-Mw
# 390498 NEIC-Mb ISC|NEIC-Mb
# 390621 NEIC-Mb ISC|NEIC-Mb
# GCMT_008281 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008282 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008283 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008284 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008285 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008286 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008287 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008288 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008289 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008290 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008291 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008292 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008293 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008294 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008295 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008296 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008297 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008298 GCMT-Mw GCMT|GCMT-Mw
# 385519 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# GCMT_008300 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008301 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008302 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008303 GCMT-Mw GCMT|GCMT-Mw
# 385738 NEIC-Mb ISC|NEIC-Mb
# GCMT_008304 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008305 GCMT-Mw GCMT|GCMT-Mw
# 385898 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# GCMT_008307 GCMT-Mw GCMT|GCMT-Mw
# 385968 ISC-Ms ISC-EHB|ISC-Ms
# GCMT_008308 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008309 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008310 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008311 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008312 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008313 GCMT-Mw GCMT|GCMT-Mw
# 386163 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# GCMT_008315 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008316 GCMT-Mw GCMT|GCMT-Mw
# 386255 NEIC-Mb ISC|NEIC-Mb
# GCMT_008317 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008318 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008319 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008320 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008321 GCMT-Mw GCMT|GCMT-Mw
# 386546 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008322 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008323 GCMT-Mw GCMT|GCMT-Mw
# 386608 ISC-Ms ISC-EHB|ISC-Ms
# GCMT_008324 GCMT-Mw GCMT|GCMT-Mw
# 386727 NEIC-Mb ISC|NEIC-Mb
# 386767 NEIC-Mb ISC|NEIC-Mb
# 386769 NEIC-Ms EHB|NEIC-Ms
# 386799 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008325 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008326 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008327 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008328 GCMT-Mw GCMT|GCMT-Mw
# 386936 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 386945 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 386946 NEIC-Mb ISC|NEIC-Mb
# GCMT_008330 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008331 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008332 GCMT-Mw GCMT|GCMT-Mw
# 387154 NEIC-Mb ISC|NEIC-Mb
# GCMT_008333 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008334 GCMT-Mw GCMT|GCMT-Mw
# 387203 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008335 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008336 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008337 GCMT-Mw GCMT|GCMT-Mw
# 387301 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008338 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008339 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008340 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008341 GCMT-Mw GCMT|GCMT-Mw
# 387468 NEIC-Mb ISC|NEIC-Mb
# GCMT_008342 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008343 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008344 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008345 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008346 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008347 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008348 GCMT-Mw GCMT|GCMT-Mw
# 387733 NEIC-Mb ISC|NEIC-Mb
# GCMT_008349 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008350 GCMT-Mw GCMT|GCMT-Mw
# 387832 GCMT-Mw ISC-EHB|GCMT-Mw
# GCMT_008352 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008353 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008354 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008355 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008356 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008357 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008358 GCMT-Mw GCMT|GCMT-Mw
# 387968 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 387969 NEIC-Mb ISC|NEIC-Mb
# 387974 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# usp00042e4 -- None --  None
# GCMT_008361 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008362 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008363 GCMT-Mw GCMT|GCMT-Mw
# 388103 NEIC-Mb ISC|NEIC-Mb
# GCMT_008364 GCMT-Mw GCMT|GCMT-Mw
# 388176 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# GCMT_008365 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008366 GCMT-Mw GCMT|GCMT-Mw
# 388311 NEIC-Mb EHB|NEIC-Mb
# GCMT_008367 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008368 GCMT-Mw GCMT|GCMT-Mw
# 388391 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008369 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008370 GCMT-Mw GCMT|GCMT-Mw
# 388429 NEIC-Mb ISC-EHB|NEIC-Mb
# 382687 ISC-Ms ISC-EHB|ISC-Ms
# 382688 NEIC-Mb ISC|NEIC-Mb
# GCMT_008371 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008372 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008373 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008374 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008375 GCMT-Mw GCMT|GCMT-Mw
# 382842 NEIC-Mb ISC|NEIC-Mb
# GCMT_008376 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008377 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008378 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008379 GCMT-Mw GCMT|GCMT-Mw
# 382913 NEIC-Mb ISC|NEIC-Mb
# GCMT_008380 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008381 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008382 GCMT-Mw GCMT|GCMT-Mw
# 383092 ISC-Mb ISC|ISC-Mb
# 383112 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008383 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008384 GCMT-Mw GCMT|GCMT-Mw
# 383182 NEIC-Mb ISC|NEIC-Mb
# 383191 NEIC-Mb ISC|NEIC-Mb
# GCMT_008385 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008386 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008387 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008388 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008389 GCMT-Mw GCMT|GCMT-Mw
# 383295 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 383298 NEIC-Mb EHB|NEIC-Mb
# GCMT_008391 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008392 GCMT-Mw GCMT|GCMT-Mw
# 383334 NEIC-Mb ISC|NEIC-Mb
# 383336 NEIC-Mb ISC|NEIC-Mb
# 383344 NEIC-Mb ISC-EHB|NEIC-Mb
# 383386 ISC-Ms ISC-EHB|ISC-Ms
# 383402 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008393 GCMT-Mw GCMT|GCMT-Mw
# 383424 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 383427 NEIC-Mb ISC|NEIC-Mb
# 383510 ISC-Mb ISC|ISC-Mb
# 383542 ISC-Ms ISC|ISC-Ms
# 383549 ISC-Ms ISC-EHB|ISC-Ms
# GCMT_008394 GCMT-Mw GCMT|GCMT-Mw
# 383641 NEIC-Mb EHB|NEIC-Mb
# GCMT_008395 GCMT-Mw GCMT|GCMT-Mw
# 383685 ISC-Ms ISC|ISC-Ms
# GCMT_008396 GCMT-Mw GCMT|GCMT-Mw
# 383835 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008397 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008398 GCMT-Mw GCMT|GCMT-Mw
# 383905 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 383908 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 383909 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 
ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 384322 ISC-Mb ISC|ISC-Mb
# 384325 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 384335 ISC-Ms ISC-EHB|ISC-Ms
# 384341 ISC-Ms ISC-EHB|ISC-Ms
# 384348 ISC-Ms ISC-EHB|ISC-Ms
# 384356 NEIC-Ms ISC|NEIC-Ms
# 384382 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 384386 NEIC-Mb ISC-EHB|NEIC-Mb
# 384387 NEIC-Mb ISC-EHB|NEIC-Mb
# 384390 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 384395 NEIC-Mb ISC|NEIC-Mb
# 384406 NEIC-Mb ISC|NEIC-Mb
# 384409 NEIC-Mb ISC|NEIC-Mb
# 384410 NEIC-Mb ISC|NEIC-Mb
# GCMT_008413 GCMT-Mw GCMT|GCMT-Mw
# 384417 NEIC-Mb EHB|NEIC-Mb
# 384425 NEIC-Mb ISC-EHB|NEIC-Mb
# 384428 NEIC-Mb ISC|NEIC-Mb
# 384430 ISC-Ms ISC-EHB|ISC-Ms
# 384433 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 384439 NEIC-Mb ISC-EHB|NEIC-Mb
# GCMT_008415 GCMT-Mw GCMT|GCMT-Mw
# 384462 NEIC-Ms ISC-EHB|NEIC-Ms
# 384469 NEIC-Mb ISC-EHB|NEIC-Mb
# 384476 NEIC-Mb ISC-EHB|NEIC-Mb
# 384480 NEIC-Mb ISC|NEIC-Mb
# 384484 ISC-Ms ISC-EHB|ISC-Ms
# 384493 ISC-Ms ISC-EHB|ISC-Ms
# 384522 NEIC-Mb ISC|NEIC-Mb
# GCMT_008416 GCMT-Mw GCMT|GCMT-Mw
# 384617 NEIC-Mb ISC-EHB|NEIC-Mb
# 384635 NEIC-Ms ISC|NEIC-Ms
# 384642 NEIC-Mb ISC|NEIC-Mb
# 384679 NEIC-Mb NEIC|NEIC-Mb
# GCMT_008417 GCMT-Mw GCMT|GCMT-Mw
# 384727 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 384739 NEIC-Mb ISC|NEIC-Mb
# 384746 NEIC-Ms ISC|NEIC-Ms
# GCMT_008418 GCMT-Mw GCMT|GCMT-Mw
# 384786 NEIC-Mb ISC-EHB|NEIC-Mb
# 384794 NEIC-Mb ISC|NEIC-Mb
# GCMT_008419 GCMT-Mw GCMT|GCMT-Mw
# 384931 NEIC-Mb ISC|NEIC-Mb
# GCMT_008420 GCMT-Mw GCMT|GCMT-Mw
# 384973 GCMT-Mw ISC-EHB|GCMT-Mw
# GCMT_008422 GCMT-Mw GCMT|GCMT-Mw
# 385042 ISC-GEM-Mw ISC-GEM|ISC-GEM-Mw
# 385093 ISC-Ms ISC-EHB|ISC-Ms
# GCMT_008423 GCMT-Mw GCMT|GCMT-Mw
# 385196 NEIC-Mb ISC|NEIC-Mb
# 385198 NEIC-Mb ISC|NEIC-Mb
# GCMT_008424 GCMT-Mw GCMT|GCMT-Mw
# 385306 NEIC-Ms ISC-EHB|NEIC-Ms
# GCMT_008425 GCMT-Mw GCMT|GCMT-Mw
# 385346 NEIC-Mb ISC|NEIC-Mb
# GCMT_008426 GCMT-Mw GCMT|GCMT-Mw
# 385366 ISC-Ms ISC-EHB|ISC-Ms
# 385372 NEIC-Mb ISC|NEIC-Mb
# GCMT_008427 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008428 GCMT-Mw GCMT|GCMT-Mw
# 385440 NEIC-Mb ISC|NEIC-Mb
# 385441 NEIC-Mb ISC-EHB|NEIC-Mb
# 385450 ISC-Ms ISC-EHB|ISC-Ms
# GCMT_008429 GCMT-Mw GCMT|GCMT-Mw
# GCMT_008430 GCMT-Mw GCMT|GCMT-Mw
# Merged Catalogue 1960-1989 contains: 125320 events

# %%
log_file = os.path.join(temp_dir, "1960-1989-merged-homogenisor_log.csv")
if os.path.exists(log_file):
    os.remove(log_file)

harmonisor_1960_1989.dump_log(log_file)
print("log file saved in Temporary directory:", log_file)
# Out:
# log file saved in Temporary directory: C:\Users\ENRICO~1.ABC\AppData\Local\Temp\tmpm4vjhaz2\1960-1989-merged-homogenisor_log.csv

# %%
output_catalogue_file = f"outputs/1960-1989-merged-homogeneous_catalogue.csv"
if os.path.exists(output_catalogue_file):
    os.remove(output_catalogue_file)
harmonisor_1960_1989.export_homogenised_to_csv(output_catalogue_file)

print("catalogue saved in cwd:", output_catalogue_file)
# Out:
# catalogue saved in cwd: outputs/1960-1989-merged-homogeneous_catalogue.csv

# %%
# Open the input and output files
input_file_path = "outputs/1960-1989-merged-homogeneous_catalogue.csv"
output_file_path = "outputs/1960-1989-merged-homogeneous_catalogue-cleaned.csv"

with open(input_file_path, "r") as input_file, open(output_file_path, "w") as output_file:
    for line in input_file:
        # Split the line into parts using commas
        parts = line.split(",")
        
        # Keep only the first 20 parts (up to the 20th comma)
        truncated_line = ",".join(parts[:20]) + "\n"
        
        # Write the modified line to the output file
        output_file.write(truncated_line)

print("CSV file manipulation completed.")
# Out:
# CSV file manipulation completed.

# %%
# Open the input and output files
input_file_path = "outputs/1960-1989-merged-homogeneous_catalogue.csv"
output_file_path = os.path.join(temp_dir, "1960-1989-merged-homogeneous_catalogue-cleaned.csv")

delimiter = ","  # Replace with your CSV delimiter

with open(input_file_path, "r") as input_file, open(output_file_path, "w") as output_file:
    for line in input_file:
        # Split the line into parts using commas
        parts = line.strip().split(delimiter)
        
        # Join the first 20 parts (up to the 20th comma) and everything after it
        truncated_parts = parts[:20] + [" || ".join(parts[20:])]
        
        # Create the modified line by joining the truncated parts
        modified_line = delimiter.join(truncated_parts) + "\n"
        
        # Write the modified line to the output file
        output_file.write(modified_line)

print("CSV file manipulation completed.")

cleaned_file_path = output_file_path
# Out:
# CSV file manipulation completed.

# %%
df = pd.read_csv(cleaned_file_path)

# Assuming your DataFrame is named df
# Filter the DataFrame based on latitude and longitude conditions
filtered_df = df[
    (df['latitude'] >= 1.89) & (df['latitude'] <= 24) &
    (df['longitude'] >= 114) & (df['longitude'] <= 129.5)
]

# Save the filtered DataFrame to a CSV file
output_csv_path = "outputs/1960-1989-merged-homogeneous_catalogue.csv"
filtered_df.to_csv(output_csv_path, index=False)

print("Filtered DataFrame saved to CSV:", output_csv_path)
# Out:
# Filtered DataFrame saved to CSV: outputs/1960-1989-merged-homogeneous_catalogue.csv

# %%
#remove the contents of the tempdir when you are done
import shutil
shutil.rmtree(temp_dir)
print("Temporary directory and its contents removed.")
# Out:
# Temporary directory and its contents removed.
