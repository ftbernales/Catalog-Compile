# %% [markdown]
# # Catalogue Query Tools

# %% [markdown]
# This notebook provides examples on how to use the Catalogue Toolkit to build and explore a catalogue database:

# %%
# %matplotlib inline
import os, sys
import numpy as np
import matplotlib.pyplot as plt
from openquake.cat.parsers.isf_catalogue_reader import ISFReader
import openquake.cat.catalogue_query_tools as cqt

# %% [markdown]
# ## Constructing the Database

# %%
# Read in the catalogue
parser = ISFReader("inputs/2021-2023-PH_ISF_Catalogue.txt")
catalogue1 = parser.read_file("ISC", "ISC-ALL")
print("Catalogue contains: %d events" % catalogue1.get_number_events())
# Out:
# Catalogue contains: 8361 events

# %%
# Build the HDF5 Database
database_file = "outputs/2021-2023catalogue_db1.hdf5"
if os.path.exists(database_file):
    os.remove(database_file)
_ = catalogue1.build_dataframe(hdf5_file=database_file)
# Out:
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927681)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927684)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927689)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927695)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927702)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927733)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626138192)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927749)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927752)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927753)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927790)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927804)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927810)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927847)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927864)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927871)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927887)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620733585)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927983)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927988)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620927998)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928001)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620752023)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928037)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928041)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620757329)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928061)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620758230)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626034565)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626034647)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626034648)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620758693)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928127)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928143)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:622449030)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620772583)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928185)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928196)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928210)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620784561)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928250)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928257)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620787252)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620787253)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620787254)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928295)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928297)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928300)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928301)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928302)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928304)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928305)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928306)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928307)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928325)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928326)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928328)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928329)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928330)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928334)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928335)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928336)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928337)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928340)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928342)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928348)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928350)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620787327)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620787326)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928393)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928400)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928421)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928435)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928440)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928441)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928463)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928486)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928490)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928496)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928508)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626034997)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626066592)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928546)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035022)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928550)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626066569)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928565)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620823838)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035056)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035113)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035209)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035227)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620823855)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035336)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035340)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035355)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035359)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035462)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620828947)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928596)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035484)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620828953)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620828955)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620829519)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035625)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035648)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621112240)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928648)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035659)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928654)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928656)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928658)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620831312)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620831313)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035764)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035768)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035795)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928701)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620832588)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928670)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035881)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035882)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:625560843)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928782)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928783)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928793)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928797)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928798)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928800)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626035997)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928804)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928809)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928840)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928847)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928857)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928866)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620833958)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620834055)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928893)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620928894)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620961594)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620961625)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620961671)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620967802)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620845121)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620967838)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620967886)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620967909)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620967934)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620967945)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620970189)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620970190)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620970201)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620970207)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620970215)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620970227)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620973749)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620973796)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620973803)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620970677)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620973810)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620973811)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620973834)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620973840)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620973849)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620978992)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620978993)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620979614)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620979628)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620979635)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620857932)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620878558)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620883000)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620986059)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620986065)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626036836)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620986092)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620986098)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620986099)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620986126)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620986134)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620986147)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620986180)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620986238)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620993189)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620993230)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620993231)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620993250)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620995854)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620995870)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620995880)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620995912)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620997287)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620998773)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620998791)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620998794)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620998806)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620998807)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620998814)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620970716)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620998888)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620970791)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620998895)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626042350)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620998898)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626042367)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626042371)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620998928)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620998929)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621000688)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621000706)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621000729)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621000737)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621002116)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621002134)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621002137)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621002149)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621007265)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626042647)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621007289)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621007290)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621008085)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621008092)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621008122)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621008128)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009337)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009345)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009350)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009352)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009355)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009360)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009366)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009368)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009370)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009375)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009381)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009398)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009418)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009428)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009430)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009432)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009433)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009434)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009437)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009443)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009445)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009501)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009537)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621009538)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621012007)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621012023)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626042833)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626042836)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621012058)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621012066)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621012128)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621013423)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621013474)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621013520)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620986723)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621013539)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621013545)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621013571)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621013572)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621023526)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621023528)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621023536)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621023550)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621148105)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621023607)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621023658)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621030239)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621030257)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621030275)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621030288)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621030291)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621030296)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621030298)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621030299)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626043208)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620997091)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626043210)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621039192)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621039198)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620997344)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626043222)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621039222)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621039228)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621041230)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621041243)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621041249)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621041280)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621041281)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621041285)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620999177)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621042965)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620999308)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621043011)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621043043)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621043059)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620999535)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:620999539)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621043106)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:621043140)
# ...
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626366981)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626366989)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626366991)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626366999)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626367853)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626367860)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626367865)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626368649)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626368684)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626368693)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626369669)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626369692)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626369700)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626369706)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626369741)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626369750)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626369761)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626369774)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626434895)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626434897)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626332659)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626333222)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626434924)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626434938)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626434942)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626434976)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626434980)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626434989)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626434992)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626434997)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626335965)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626335968)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626446835)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626446839)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626446862)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626446874)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626446876)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626446881)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626460756)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626460764)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626460770)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626460772)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626460777)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626460793)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626460804)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626491079)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626491133)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626491149)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626491158)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626491163)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626491170)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626491189)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626519037)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626519038)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626519045)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626519050)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626519060)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626519069)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626519077)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626519097)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626519100)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626519104)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626519114)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626519125)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626356932)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626356942)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626519149)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626519155)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626519169)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626529599)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626529627)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626529631)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626529671)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626365471)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626529701)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626366108)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626529705)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626529710)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626529712)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626529713)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626534967)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626366122)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626534969)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626534971)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626366127)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626534974)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626366131)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626366133)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626534992)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626535006)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626537401)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626366456)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626367027)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626537420)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626540238)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626540261)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626540268)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626540212)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626368887)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626540219)
#   warnings.warn(fmt.format(eq.id))
# C:\Users\enrico.abcede\mbtk\oq-mbtk\openquake\cat\isf_catalogue.py:1212: UserWarning: Warning, depth <= 0.0 (id:626540221)
#   warnings.warn(fmt.format(eq.id))

# %% [markdown]
# ## Using the Database

# %%
db1 = cqt.CatalogueDB(database_file)

# %% [markdown]
# ### Apply Limiting Selections

# %% [markdown]
# #### By Bounding Box

# %%
lower_lon = 0
upper_lon = 180
lower_lat = 0
upper_lat = 180
bbox = [lower_lon, upper_lon, lower_lat, upper_lat]
selector = cqt.CatalogueSelector(db1)
aegean_cat = selector.select_within_bounding_box(bbox)

# %%
number_origins, number_magnitudes = aegean_cat._get_number_origins_magnitudes()
print("Number of Origins = %d, Number of Magnitudes = %d" % (number_origins,
                                                             number_magnitudes))

# %% [markdown]
# #### By Polygon

# %%
polygon = np.array([[15.0, 45.0],
                    [30.0, 45.0],
                    [30.0, 30.0],
                    [15.0, 30.0],
                    [15.0, 45.0]])
selector2 = cqt.CatalogueSelector(db1)
aegean_cat_alt = selector2.select_within_polygon(polygon[:, 0], polygon[:, 1])
number_origins, number_magnitudes = aegean_cat_alt._get_number_origins_magnitudes()
print("Number of Origins = %d, Number of Magnitudes = %d" % (number_origins,
                                                             number_magnitudes))

# %% [markdown]
# #### By Magnitude

# %%
# Above magnitude 6.0
selector3 = cqt.CatalogueSelector(aegean_cat)
aegean_cat_m6 = selector3.select_within_magnitude_range(lower_mag=6.0, upper_mag=9.0)
number_origins, number_magnitudes = aegean_cat_m6._get_number_origins_magnitudes()
print("Number of Origins = %d, Number of Magnitudes = %d" % (number_origins,
                                                             number_magnitudes))

# %% [markdown]
# #### By Depth

# %%
selector4 = cqt.CatalogueSelector(aegean_cat_alt)
aegean_cat_deep = selector4.select_within_depth_range(upper_depth=50.0, lower_depth=200.0)
number_origins, number_magnitudes = aegean_cat_deep._get_number_origins_magnitudes()
print("Number of Origins = %d, Number of Magnitudes = %d" % (number_origins,
                                                             number_magnitudes))

# %% [markdown]
# ## Exploring the Catalogue Database

# %% [markdown]
# ### See Summary of Agencies and Magnitudes in the Catalogue

# %%
agency_count = cqt.get_agency_magtype_statistics(db1)
# Out:
# Agency: IDC - 6140 Origins
# mb (6140) | mbtmp (6140) | MS (3164) | ML (1883)
# ========================================
# Agency: NEIC - 3081 Origins
# mb (2507) | Mww (176) | UK (98) | Mwr (53) | Ms_20 (49) | Mwb (46) | Mwc (4) | MB (1) | Mwp (1)
# ========================================
# Agency: TAP - 1938 Origins
# ML (1938)
# ========================================
# Agency: GFZ - 975 Origins
# mb (1084) | M (963) | mB (677) | UK (585) | ML (470) | Mwp (233) | MwMwp (155) | MLv (118) | Mw(mB (92) | Mw (91) | MW (22)
# ========================================
# Agency: MOS - 595 Origins
# MB (460) | mb (130) | MS (82) | Mb (1)
# ========================================
# Agency: DJA - 345 Origins
# MLv (343) | mb (208) | mB (126) | Mwp (23) | Mw (18) | ML (8)
# ========================================
# Agency: BJI - 336 Origins
# mb (350) | mB (330) | Ms (279) | Ms7 (278) | ML (109)
# ========================================
# Agency: GCMT - 295 Origins
# MW (292) | MS (3)
# ========================================
# Agency: NIED - 279 Origins
# MW (279)
# ========================================
# Agency: AUST - 270 Origins
# Mw (214) | mb (92) | MLv (79) | Mwp (74) | ML (63) | MwMwp (36) | Mww (4)
# ========================================
# Agency: JMA - 214 Origins
# MV (182) | MD (12) | MW (4) | Mw (1)
# ========================================
# Agency: MAN - 204 Origins
# mb (204) | ML (204) | MS (204)
# ========================================
# Agency: ASIES - 195 Origins
# Mw (195)
# ========================================
# Agency: DMN - 102 Origins
# Mb (102)
# ========================================
# Agency: CSEM - 76 Origins
# Mw (3) | mb (2)
# ========================================
# Agency: DSN - 68 Origins
# mb (68) | Ms (29)
# ========================================
# Agency: KEA - 59 Origins
# mB (43) | Ms (35)
# ========================================
# Agency: PTWC - 51 Origins
# Mwp (51) | Mw (1)
# ========================================
# Agency: IPGP - 49 Origins
# Mw (49)
# ========================================
# Agency: NOU - 45 Origins
# mb (34) | MLv (8) | MwMwp (3)
# ========================================
# Agency: SFS - 23 Origins
# mb (23) | ML (23) | mB (22) | UK (21) | MwMwp (20) | Mwp (20) | Mw(mB (1)
# ========================================
# Agency: BGR - 15 Origins
# mb (18) | Ms (12) | mB_BB (3)
# ========================================
# Agency: BUC - 12 Origins
# Mb (1)
# ========================================
# Agency: SJA - 9 Origins
# No magnitudes corresponding to this agency
# ========================================
# Agency: VAO - 9 Origins
# mb (9)
# ========================================
# Agency: NAO - 8 Origins
# MB (7) | Mb (2) | ML (1)
# ========================================
# Agency: RSNC - 4 Origins
# UK (2) | MLv (1) | mb (1) | mB (1)
# ========================================
# Agency: SNET - 3 Origins
# M (6) | mb (6) | mB (6) | Mjma (6) | MLv (6) | UK (6) | MwMwp (5) | Mwp (5)
# ========================================
# Agency: WEL - 2 Origins
# M (2) | mB (2) | Mw(mB (1) | UK (1)
# ========================================
# Agency: ROM - 2 Origins
# mb (2) | Mwp (2) | Mwpd (2) | Mw (1)
# ========================================
# Agency: DNK - 1 Origins
# mb (1)
# ========================================
# Agency: JSO - 1 Origins
# M (1)
# ========================================
# Agency: TIR - 1 Origins
# MB (1)
# ========================================
# Agency: OSUNB - 1 Origins
# mb (1)
# ========================================
# Agency: CATAC - 1 Origins
# M (1) | mb (1) | mB (1) | UK (1) | MwMwp (1) | Mwp (1)
# ========================================
# Agency: BER - 1 Origins
# ML (1)
# ========================================
# Agency: IRIS - 1 Origins
# No magnitudes corresponding to this agency
# ========================================
# Agency: UCR - 1 Origins
# No magnitudes corresponding to this agency
# ========================================
# Agency: USGS - 1 Origins
# No magnitudes corresponding to this agency
# ========================================

# %% [markdown]
# ### Search for a Specific Agency-Magnitude Combination

# %% [markdown]
# Search for body-wave magnitude common to 'BJI' and 'ISC'

# %%
query_NEIC_GCMT_mw, NEIC_GCMT_mw_cat = cqt.get_agency_magnitude_pairs(db1, ("NEIC", "Mw"), ("GCMT", "Mw"), no_case=True)

# %%
query_NEIC_GCMT_mw

# %%
_ = cqt.plot_agency_magnitude_density(query_NEIC_GCMT_mw)

# %% [markdown]
# ### Join Query Results

# %% [markdown]
# Join together the results of two queries. For example the Global CMT magnitudes are reported under either
# 'GCMT' or 'HRVD'. So search for both terms

# %%
query1, cat1 = cqt.get_agency_magnitude_pairs(db1, ("GCMT", "Mw"), ("NEIC", "Ms"), no_case=True)
query2, cat2 = cqt.get_agency_magnitude_pairs(db1, ("GCMT", "Mw"), ("NEIS", "Mw"), no_case=True)
query_niec_gcmt_ms = cqt.join_query_results(query1, query2)

# %%
_ = cqt.plot_agency_magnitude_density(query_niec_gcmt_ms)

# %% [markdown]
# ## Regression Tools

# %% [markdown]
# In this example we compare the $M_S$ scale as recorded by the BJI network with the $M_W$ scale reported by
# HRVD/GCMT (from the previous query)

# %% [markdown]
# #### Set up the regression

# %%
regressor = cqt.CatalogueRegressor(query_niec_gcmt_ms)
regressor.plot_density(overlay=False)

# %% [markdown]
# #### Apply a Linear Model

# %%
linear_model = regressor.run_regression("polynomial", # Model Type
                                        [0., 1.]) # Initial guess of parameters
regressor.plot_model_density(False, 0)
# View Results
print("Mw = %.3f + %.3f MS +/- %.3f" % (regressor.results.beta[0],
                                        regressor.results.beta[1],
                                        regressor.standard_deviation))

# %% [markdown]
# #### Overlay another model defined as a Magnitude Conversion Rule

# %%
from openquake.cat.isc_homogenisor import MagnitudeConversionRule
# Define empirical model
def RandomRule1(magnitude):
    return 1.21 + 0.84 * magnitude

def RandomRuleSigma(magnitude):
    return 0.2
# Create Rule
rule1 = MagnitudeConversionRule("BJI", "MS", RandomRule1, RandomRuleSigma,
                                model_name=r"$M_{W_{GCMT}} = 1.2 + 0.767 M_{S_{BJI}}$")
# Plot the model - with overla set to true
regressor.plot_model_density(True, 0)
# Overlay the rule and close the figure (overlay set to False)
regressor.plot_magnitude_conversion_model(rule1, False, line_color="b")

# %% [markdown]
# ### Apply a Piecewise Linear Model

# %%
initial_guess = [1.0, 1.0, 0.0]  # [slope 1, slope 2, intercept]

linear_model = regressor.run_regression("2segmentM6.1", # Model Type
                                        initial_guess) # Initial guess of parameters
regressor.plot_model_density(False, 0)
print("Standard Deviation - Segment 1: %.3f, Segment 2: %.3f" % (regressor.standard_deviation[0],
                                                                 regressor.standard_deviation[1]))
